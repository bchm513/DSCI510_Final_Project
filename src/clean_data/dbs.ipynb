# %%
import pandas as pd

dbs = pd.read_csv('dbs.csv')

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import plot_tree

import matplotlib.pyplot as plt

drop_cols = [
    'index', 'player_id', 'player', 'pff_player_id', 'position', 'unit',
    'season_1', 'position_1', 'season',
    'run_block_snaps', 'receiving_snaps', 'pass_block_snaps', 'run_snaps', 'pass_snaps',
    'run_block', 'receiving', 'pass_block', 'run', 'pass', 'offense',
    'pass_rush_rank', 'receiving_rank', 'pass_rank', 'run_block_rank', 'pass_block_rank', 'run_rank',
    'season_1', 'position_1', 'pff_player_id'
]

dbs_clean = dbs.drop(columns=[c for c in drop_cols if c in dbs.columns])
# tot_clean

target_cols = ['wick_score', 'capped_wick_score']
X = dbs_clean.drop(columns=target_cols)
y = dbs_clean[target_cols]

X_numeric = X.select_dtypes(include='number')

# Impute
imputer = SimpleImputer(strategy='median')
X_imputed_array = imputer.fit_transform(X_numeric)

# Only use the columns that were actually imputed
X_imputed = pd.DataFrame(X_imputed_array, columns=X_numeric.columns[:X_imputed_array.shape[1]])

scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X_imputed), columns=X_imputed.columns)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y['wick_score'], test_size=0.2, random_state=42
)

# print(X_numeric.columns)
# print(X_imputed.columns)
# print(X_train.columns)
# Out:
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_base.py:653: UserWarning: Skipping features without any observed values: ['offense_rank']. At least one non-missing value is needed for imputation with strategy='median'.
#   warnings.warn(

# %%
# ----------------------
# Random Forest model
# ----------------------
rf = RandomForestRegressor(n_estimators=500, max_depth=4, random_state=42)
rf.fit(X_train, y_train)

# print(X.columns)
# print(X_train.columns)

feature_importance_rf = pd.Series(rf.feature_importances_, index=X_train.columns).sort_values(ascending=False)
# print("\nTop features by Random Forest:")
# print(feature_importance_rf)

plt.figure(figsize=(10, 6))
feature_importance_rf.plot(kind='bar')
plt.title("Top Features by Random Forest")
plt.ylabel("Importance")
plt.xlabel("Features")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

plt.figure(figsize=(20, 10))
# Plot the first tree in the forest
plot_tree(
    rf.estimators_[0],
    feature_names=X.columns,
    filled=True,
    rounded=True,
    fontsize=10
)
plt.title("Random Forest - First Tree Visualization")
plt.show()

# %%
# ----------------------
# LassoCV model
# ----------------------
lasso = LassoCV(cv=5, random_state=42)
lasso.fit(X_train, y_train)

# Feature importance
feature_importance_lasso = pd.Series(lasso.coef_, index=X_train.columns).sort_values(ascending=False)
# print("Top features by LassoCV:")
# print(feature_importance_lasso)

plt.figure(figsize=(10, 6))
feature_importance_lasso_abs = feature_importance_lasso.abs().sort_values(ascending=False)
feature_importance_lasso_abs.plot(kind='bar', color='orange')
plt.title("Top Features by LassoCV (Absolute Coefficients)")
plt.ylabel("Coefficient Magnitude")
plt.xlabel("Features")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.409e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.456e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.025e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.284e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.317e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.306e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.288e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.262e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.216e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.163e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.105e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.044e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.980e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.916e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.851e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.786e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.723e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.660e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.599e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.540e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.483e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.427e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.374e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.324e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.275e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.229e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.185e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.143e+00, tolerance: 5.750e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.640e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.132e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.484e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.589e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.627e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.637e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.626e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.588e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.510e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.452e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.558e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.427e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.529e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.256e-01, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.782e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.050e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.461e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.479e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.430e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.369e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.309e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.251e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.194e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.140e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.088e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.038e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.991e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.946e+00, tolerance: 8.402e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.129e-01, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.149e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.678e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.758e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.755e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.735e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.711e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.685e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.658e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.630e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.602e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.575e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.547e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.291e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.447e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.528e+00, tolerance: 7.704e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.873e-01, tolerance: 6.734e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.251e+00, tolerance: 6.734e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.337e-01, tolerance: 6.734e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.103e+00, tolerance: 6.734e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.718e+00, tolerance: 6.734e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.073e+00, tolerance: 6.734e-01
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.132e+00, tolerance: 6.734e-01
#   model = cd_fast.enet_coordinate_descent_gram(
