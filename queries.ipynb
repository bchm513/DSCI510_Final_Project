# %%
import duckdb
import pandas as pd

team_defense_snaps = pd.read_csv('intermediate_content/team_defense_snaps.csv')  
team_offense_snaps = pd.read_csv('intermediate_content/team_offense_snaps.csv')
transfer_player_career_wicks = pd.read_csv('intermediate_content/transfer_player_career_wicks.csv')
transfer_player_snap_counts = pd.read_csv('intermediate_content/transfer_player_snap_counts.csv')
transfer_player_career_wicks
# Out:
#        season position  pff_player_id  wick_score  capped_wick_score
# 0        2024       QB         149182        52.7               44.4
# 1        2024       QB         105568        65.0               60.5
# 2        2024       QB         158683        45.7               35.3
# 3        2024       QB         122162        50.3               41.3
# 4        2024       QB         129906        53.6               45.6
# ...       ...      ...            ...         ...                ...
# 20329    2025        S         157707        54.2               54.2
# 20330    2025        S         145579        46.9               46.9
# 20331    2025        S         123103        50.7               50.7
# 20332    2025        S         170434        39.5               39.5
# 20333    2025        S         172021        50.1               50.1
#
# [20334 rows x 5 columns]

# %%
# find players who go up in some way (fcs to group of 6, group of 6 to power 4)

moved_up_df = transfer_player_snap_counts[
    (
        (transfer_player_snap_counts["prev_level"] == "FCS") &
        (transfer_player_snap_counts["current_level"].isin(["Power Four", "Group of Six"]))
    )
    |
    (
        (transfer_player_snap_counts["prev_level"] == "Group of Six") &
        (transfer_player_snap_counts["current_level"] == "Power Four")
    )
]
# moved_up_df

# %%
# find players who succeeded in their moved up schools

succeeded_df = moved_up_df[
    (moved_up_df["current_def_snaps"] > 100) |
    (moved_up_df["current_off_snaps"] > 100)
]

succeeded_df.to_csv("succeeded.csv", index=False)

succeeded_df
# Out:
#        pff_player_id          player_name  prev_season  current_season  \
# 0              21922        Mark Williams         2020            2021
# 7              23441  Reggie Stubblefield         2020            2021
# 13             28919       Jawon Hamilton         2020            2021
# 16             30285         Colby Reeder         2021            2022
# 17             30557         Adam Cofield         2020            2021
# ...              ...                  ...          ...             ...
# 15130         189285          Ayden Jones         2024            2025
# 15220         190753      Joseph Williams         2024            2025
# 15271         192037       Anthony Palano         2024            2025
# 15276         192135         Baylor Hayes         2024            2025
# 15292         192936        Matthew Henry         2024            2025
#
#       prev_position current_pos prev_gsis           prev_school current_gsis  \
# 0                CB          CB      ILEA      Eastern Illinois         LANE
# 7                CB           S      TXPV      Prairie View A&M         KSST
# 13               HB          HB      VAJM         James Madison         MIEA
# 16               LB          LB      DEUN              Delaware         IAST
# 17               HB          HB      NDST    North Dakota State         KYWE
# ...             ...         ...       ...                   ...          ...
# 15130            LB          LB      TXPV      Prairie View A&M         TXSW
# 15220            WR          WR      OKTU                 Tulsa         COUN
# 15271            LB          LB      SDST    South Dakota State         WAST
# 15276            QB          QB      TNEA  East Tennessee State         OKTU
# 15292            WR          WR      ILWE      Western Illinois         KYWE
#
#          current_school    prev_level current_level  prev_def_snaps  \
# 0      Louisiana-Monroe           FCS  Group of Six           348.0
# 7          Kansas State           FCS    Power Four           185.0
# 13     Eastern Michigan           FCS  Group of Six             NaN
# 16           Iowa State           FCS    Power Four           441.0
# 17     Western Kentucky           FCS  Group of Six             NaN
# ...                 ...           ...           ...             ...
# 15130       Texas State           FCS  Group of Six           370.0
# 15220          Colorado  Group of Six    Power Four             NaN
# 15271  Washington State           FCS  Group of Six             NaN
# 15276             Tulsa           FCS  Group of Six             NaN
# 15292  Western Kentucky           FCS  Group of Six             NaN
#
#        current_def_snaps  prev_off_snaps  current_off_snaps
# 0                  303.0             NaN                NaN
# 7                  501.0             NaN                NaN
# 13                   NaN           170.0              227.0
# 16                 361.0             NaN                NaN
# 17                   NaN            41.0              390.0
# ...                  ...             ...                ...
# 15130              113.0             NaN                NaN
# 15220                NaN           490.0              128.0
# 15271              103.0             NaN                NaN
# 15276                NaN            80.0              110.0
# 15292                NaN           687.0              132.0
#
# [1406 rows x 16 columns]

# %%
query_1 = duckdb.query("""

SELECT prev_position, count(*) count
FROM succeeded_df
GROUP BY prev_position
ORDER BY count
""").to_df()
query_1
# Out:
#    prev_position  count
# 0             FB      2
# 1              C     45
# 2             QB     59
# 3             HB     64
# 4             TE     75
# 5              G     82
# 6             DI    111
# 7             LB    122
# 8              S    128
# 9              T    137
# 10            ED    153
# 11            WR    213
# 12            CB    215

# %%
succeeded_expanded_df_raw = duckdb.query("""

SELECT transfer_player_career_wicks.pff_player_id, player_name, prev_season, current_season, wick_score, capped_wick_score, prev_position, current_pos, prev_school, current_school, prev_def_snaps, current_def_snaps, prev_off_snaps, current_off_snaps
FROM transfer_player_career_wicks JOIN succeeded.csv succeeded ON transfer_player_career_wicks.pff_player_id = succeeded.pff_player_id
WHERE current_pos = prev_position
""").to_df()

# succeeded_expanded_df_raw

# %%
succeeded_expanded_df = duckdb.query("""

SELECT pff_player_id, player_name, prev_season, current_season, prev_position, current_pos, prev_school, current_school, 
        round(avg(wick_score), 1) wick_score, round(avg(capped_wick_score), 1) capped_wick_score, avg(prev_def_snaps) prev_def_snaps, 
        avg(current_def_snaps) current_def_snaps, avg(prev_off_snaps) prev_off_snaps, avg(current_off_snaps) current_off_snaps
FROM succeeded_expanded_df_raw
GROUP BY pff_player_id, player_name, prev_season, current_season, prev_position, current_pos, prev_school, current_school
""").to_df()

# succeeded_expanded_df

succeeded_def_df = succeeded_expanded_df[(succeeded_expanded_df["current_def_snaps"] > succeeded_expanded_df["current_off_snaps"])]
succeeded_def_df.to_csv("succeeded_def.csv", index=False)

succeeded_off_df = succeeded_expanded_df[(succeeded_expanded_df["current_def_snaps"] < succeeded_expanded_df["current_off_snaps"])]
succeeded_off_df.to_csv("succeeded_off.csv", index=False)

succeeded_expanded_df.to_csv("succeeded_expanded.csv", index=False)

succeeded_concat_df = pd.concat([succeeded_off_df, succeeded_def_df], ignore_index=True)
succeeded_concat_df.to_csv("succeeded_concat.csv", index=False)



positions_df = succeeded_expanded_df["current_pos"].isin(["LB", "CB", "WR", "ED"])
filtered = succeeded_expanded_df[positions_df]
filtered
# Out:
#       pff_player_id       player_name  prev_season  current_season  \
# 13           160110  Andrew Armstrong         2022            2023
# 14           160756     Kevin Coleman         2022            2023
# 15           104059    Da'Quan Felton         2022            2023
# 16           157048       Omari Kelly         2024            2025
# 17           144279       Eric Rivers         2024            2025
# ...             ...               ...          ...             ...
# 1126         168425        Dyoni Hill         2023            2024
# 1127         168495       Trent Henry         2023            2024
# 1128         172213      Dontez Fagan         2023            2024
# 1129         172259    D'Angelo Ponds         2023            2024
# 1130         172547        Will James         2024            2025
#
#      prev_position current_pos            prev_school  current_school  \
# 13              WR          WR         East Texas A&M        Arkansas
# 14              WR          WR          Jackson State      Louisville
# 15              WR          WR          Norfolk State   Virginia Tech
# 16              WR          WR       Middle Tennessee  Michigan State
# 17              WR          WR  Florida International    Georgia Tech
# ...            ...         ...                    ...             ...
# 1126            CB          CB               Marshall      Miami (FL)
# 1127            CB          CB        Grambling State            Troy
# 1128            CB          CB              Charlotte   West Virginia
# 1129            CB          CB          James Madison         Indiana
# 1130            CB          CB          Southern Miss         Houston
#
#       wick_score  capped_wick_score  prev_def_snaps  current_def_snaps  \
# 13          70.6               70.8             1.0                NaN
# 14          67.7               67.9             1.0                2.0
# 15          50.1               49.7             NaN                1.0
# 16          48.7               48.6             1.0                NaN
# 17          56.7               56.8             NaN                NaN
# ...          ...                ...             ...                ...
# 1126        55.9               55.9           671.0              375.0
# 1127        39.5               39.5           257.0              315.0
# 1128        57.3               57.3           628.0              528.0
# 1129        64.6               64.6           715.0              706.0
# 1130        72.2               72.2           643.0              120.0
#
#       prev_off_snaps  current_off_snaps
# 13             667.0              711.0
# 14             489.0              389.0
# 15             491.0              632.0
# 16             525.0              155.0
# 17             614.0              124.0
# ...              ...                ...
# 1126             NaN                NaN
# 1127             NaN                NaN
# 1128             NaN                NaN
# 1129             NaN                NaN
# 1130             1.0                NaN
#
# [600 rows x 14 columns]

# %%
query = duckdb.query("""

SELECT prev_position prev, count(*) count1
FROM succeeded_expanded_df
GROUP BY prev
ORDER BY count1
""").to_df()
query
# Out:
#    prev  count1
# 0     C      30
# 1    QB      52
# 2    HB      56
# 3     G      62
# 4    TE      71
# 5    DI      80
# 6     T      89
# 7     S      94
# 8    LB     102
# 9    ED     126
# 10   CB     166
# 11   WR     206

# %%
query_2 = duckdb.query("""

SELECT prev, count1, count1/count rate
FROM query JOIN query_1 ON query.prev = query_1.prev_position
ORDER BY count1
""").to_df()
query_2
# Out:
#    prev  count1      rate
# 0     C      30  0.666667
# 1    QB      52  0.881356
# 2    HB      56  0.875000
# 3     G      62  0.756098
# 4    TE      71  0.946667
# 5    DI      80  0.720721
# 6     T      89  0.649635
# 7     S      94  0.734375
# 8    LB     102  0.836066
# 9    ED     126  0.823529
# 10   CB     166  0.772093
# 11   WR     206  0.967136

# %%
# establish the list of ids that I need to add to an excel sheet

positions = ["WR", "LB", "ED", "CB"]

succeeded_ids_df = succeeded_expanded_df[["pff_player_id", "player_name", "prev_season"]][succeeded_expanded_df["prev_position"].isin(positions)]
# succeeded_ids_df = succeeded_ids_df[succeeded_expanded_df["prev_position"].isin(positions)]


succeeded_ids_df.to_csv("succeeded_ids.csv", index=False)

succeeded_ids_df
# Out:
#       pff_player_id       player_name  prev_season
# 13           160110  Andrew Armstrong         2022
# 14           160756     Kevin Coleman         2022
# 15           104059    Da'Quan Felton         2022
# 16           157048       Omari Kelly         2024
# 17           144279       Eric Rivers         2024
# ...             ...               ...          ...
# 1126         168425        Dyoni Hill         2023
# 1127         168495       Trent Henry         2023
# 1128         172213      Dontez Fagan         2023
# 1129         172259    D'Angelo Ponds         2023
# 1130         172547        Will James         2024
#
# [600 rows x 3 columns]

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\bchm5\AppData\Local\Programs\Python\Python312\python.exe

# %%
import os
import json
import shutil
import asyncio
import aiohttp
from tenacity import retry, stop_after_attempt, wait_exponential
import pandas as pd
import time 
from dotenv import load_dotenv
load_dotenv()

# print("API Key from env:", os.environ.get("PFF_API"))

@retry(stop=stop_after_attempt(10), wait=wait_exponential(multiplier=1, min=1, max=10))
async def get_jwt_token(auth_url='https://api.profootballfocus.com/auth/login'):
    async with aiohttp.ClientSession() as session:
        data = {
            'x-api-key':os.environ['PFF_API']
        }
        async with session.post(auth_url, headers=data) as resp:
            resp.raise_for_status()
            result = await resp.json()
            return result["jwt"]

@retry(stop=stop_after_attempt(10), wait=wait_exponential(multiplier=1, min=1, max=10))
async def fetch(session, url, token_ref):

    headers = {'Authorization': f'Bearer {token_ref["token"]}'}
    async with session.get(url, timeout=10, headers=headers) as resp:
        if resp.status == 401:
            token_ref['token'] = await get_jwt_token()
        else:
            resp.raise_for_status()
        return await resp.json()
    
async def fetch_all(key, urls, max_concurrency=20):
    token = await get_jwt_token()
    token_ref = {'token':token}
    results = []
    semaphore = asyncio.Semaphore(max_concurrency)  # throttle requests
    async with aiohttp.ClientSession() as session:
        async def bound_fetch(url):
            async with semaphore:
                return await fetch(session, url, token_ref)

        tasks = [asyncio.create_task(bound_fetch(url)) for url in urls]
        for task in asyncio.as_completed(tasks):
            result = await task
            results.append(result)
    print(f"Finished {key}")
    return results

BASE_URL = "https://api.profootballfocus.com/v1/grades/ncaa/{season}/season_grade"

seasons = [2019, 2020, 2021, 2022, 2023, 2024]

urls = [BASE_URL.format(season=season) for season in seasons]
# print(urls)

results = await fetch_all("season_grades", urls)

with open("season_grades.json", "w") as f:
    json.dump(results, f, indent=2)
# Out:
# Finished season_grades

# %%
import json

with open("season_grades.json", "r") as fin:
    data = json.load(fin)

with open("season_grades_filtered.json", "a") as f:
    f.write("[\n")
    for obj in data:
        # Loop through each player in the season
        for player in obj["season_grade"]:      
            for i, v in succeeded_ids_df.iterrows():
                iter_pff_player_id = v["pff_player_id"]
                iter_prev_season = v["prev_season"]

                if player["player_id"] == iter_pff_player_id and player["season"] == iter_prev_season:
                    json.dump(player, f, indent=2)
                    f.write(",")
                    print(player)

                        
            # print(player)
        
        

# print(keep_dict)
# Out:
# {'position': 'ED', 'unit': 'defense', 'week': 4, 'player_id': 55198, 'season': 2020, 'run_defense_snaps': 28, 'run_defense': 66.6, 'player': 'Jordan Strachan', 'pass_rush_snaps': 25, 'pass_rush': 56.6, 'discipline': 82.1, 'defense': 60.1, 'coverage_snaps': 14, 'coverage_rank': 43, 'coverage': 54.8, 'total_snaps': 69}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 42095, 'season': 2020, 'run_block_snaps': 41, 'run_block': 50.1, 'receiving_snaps': 47, 'receiving': 59.1, 'player': 'Jahcour Pearson', 'offense_rank': 170, 'offense': 58.0, 'discipline': 77.8, 'total_snaps': 88}
# {'position': 'CB', 'unit': 'defense', 'week': 4, 'player_id': 121345, 'season': 2020, 'run_defense_snaps': 33, 'run_defense': 88.0, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'Elijah Culp', 'offense': 60.0, 'discipline': 78.0, 'defense': 51.9, 'coverage_snaps': 29, 'coverage': 41.7, 'total_snaps': 97}
# {'position': 'LB', 'unit': 'defense', 'week': 4, 'player_id': 63327, 'season': 2020, 'run_defense_snaps': 28, 'run_defense': 66.6, 'player': 'Zack Woodard', 'pass_rush_snaps': 7, 'pass_rush': 52.1, 'discipline': 75.2, 'defense_rank': 78, 'defense': 69.0, 'coverage_snaps': 40, 'coverage_rank': 36, 'coverage': 70.7, 'total_snaps': 75}
# {'position': 'CB', 'unit': 'defense', 'week': 4, 'player_id': 136842, 'season': 2020, 'run_defense_snaps': 49, 'run_defense_rank': 128, 'run_defense': 61.6, 'player': 'Ridge Texada', 'pass_rush_snaps': 14, 'pass_rush_rank': 55, 'pass_rush': 49.7, 'discipline': 82.1, 'defense_rank': 179, 'defense': 60.7, 'coverage_snaps': 47, 'coverage_rank': 155, 'coverage': 62.6, 'total_snaps': 110}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 102599, 'season': 2020, 'run_block_snaps': 55, 'run_block': 73.1, 'receiving_snaps': 189, 'receiving_rank': 31, 'receiving': 72.9, 'player': 'Ben Ratzlaff', 'pass_block_snaps': 1, 'pass_block': 62.1, 'offense_rank': 38, 'offense': 72.3, 'discipline': 0.0, 'total_snaps': 245}
# {'position': 'CB', 'unit': 'defense', 'week': 4, 'player_id': 65033, 'season': 2020, 'run_defense_snaps': 40, 'run_defense_rank': 158, 'run_defense': 58.1, 'player': 'Akayleb Evans', 'discipline': 0.0, 'defense': 58.1, 'coverage_snaps': 25, 'coverage': 62.4, 'total_snaps': 70}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 84317, 'season': 2020, 'run_block_snaps': 34, 'run_block': 62.0, 'receiving_snaps': 41, 'receiving': 64.2, 'player': 'Harry Ballard III', 'offense': 64.8, 'discipline': 81.3, 'total_snaps': 75}
# {'position': 'CB', 'unit': 'defense', 'week': 4, 'player_id': 56122, 'season': 2020, 'run_defense_snaps': 56, 'run_defense_rank': 226, 'run_defense': 33.9, 'player': 'Cam Johnson', 'discipline': 0.0, 'defense_rank': 164, 'defense': 61.8, 'coverage_snaps': 95, 'coverage_rank': 50, 'coverage': 71.4, 'total_snaps': 167}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 89497, 'season': 2020, 'run_block_snaps': 56, 'run_block': 57.9, 'receiving_snaps': 54, 'receiving_rank': 2, 'receiving': 85.4, 'player': 'Izaiah Gathings', 'pass_block_snaps': 1, 'pass_block': 61.9, 'offense_rank': 3, 'offense': 85.0, 'discipline': 80.9, 'total_snaps': 111}
# {'position': 'ED', 'unit': 'defense', 'week': 4, 'player_id': 36723, 'season': 2020, 'run_defense_snaps': 61, 'run_defense_rank': 64, 'run_defense': 67.8, 'player': 'Elijah Taylor', 'pass_rush_snaps': 33, 'pass_rush_rank': 233, 'pass_rush': 55.9, 'discipline': 77.8, 'defense_rank': 99, 'defense': 65.1, 'total_snaps': 108}
# {'position': 'CB', 'unit': 'defense', 'week': 4, 'player_id': 102462, 'season': 2020, 'run_defense_snaps': 123, 'run_defense_rank': 50, 'run_defense': 71.5, 'player': 'Tra Fluellen', 'pass_rush_snaps': 4, 'pass_rush_rank': 33, 'pass_rush': 57.6, 'discipline': 84.9, 'defense_rank': 271, 'defense': 46.8, 'coverage_snaps': 140, 'coverage_rank': 286, 'coverage': 39.2, 'total_snaps': 313}
# {'position': 'CB', 'unit': 'defense', 'week': 4, 'player_id': 65081, 'season': 2020, 'run_defense_snaps': 18, 'run_defense': 72.7, 'player': 'Allie Green IV', 'discipline': 75.2, 'defense': 44.8, 'coverage_snaps': 18, 'coverage': 38.3, 'total_snaps': 37}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 97288, 'season': 2020, 'run_block_snaps': 14, 'run_block': 58.1, 'receiving_snaps': 23, 'receiving': 47.9, 'player': 'Tahj Washington', 'offense': 48.3, 'discipline': 76.9, 'total_snaps': 48}
# {'position': 'CB', 'unit': 'defense', 'week': 4, 'player_id': 21922, 'season': 2020, 'run_defense_snaps': 47, 'run_defense_rank': 127, 'run_defense': 61.8, 'player': 'Mark Williams', 'discipline': 78.2, 'defense_rank': 97, 'defense': 67.0, 'coverage_snaps': 64, 'coverage_rank': 93, 'coverage': 67.4, 'total_snaps': 111}
# {'position': 'WR', 'unit': 'offense', 'run': 63.2, 'week': 4, 'player_id': 102929, 'season': 2020, 'run_snaps': 1, 'run_block_snaps': 25, 'run_block': 46.9, 'receiving_snaps': 63, 'receiving_rank': 143, 'receiving': 61.0, 'player': 'Kaylon Geiger', 'offense_rank': 145, 'offense': 60.8, 'discipline': 80.4, 'total_snaps': 90}
# {'position': 'WR', 'unit': 'offense', 'run': 60.3, 'pass': 46.8, 'week': 4, 'player_id': 102597, 'season': 2020, 'run_snaps': 1, 'run_block_snaps': 48, 'run_block': 60.3, 'receiving_snaps': 180, 'receiving_rank': 14, 'receiving': 77.5, 'player': 'Jerreth Sterns', 'pass_snaps': 1, 'pass_rank': 22, 'offense_rank': 16, 'offense': 76.8, 'discipline': 85.3, 'total_snaps': 247}
# {'position': 'CB', 'unit': 'defense', 'week': 4, 'player_id': 76681, 'season': 2020, 'run_defense_snaps': 114, 'run_defense_rank': 120, 'run_defense': 63.0, 'player': 'Jeremy Webb', 'pass_rush_snaps': 0, 'pass_rush': 60.0, 'discipline': 2.8, 'defense_rank': 89, 'defense': 67.7, 'coverage_snaps': 132, 'coverage_rank': 73, 'coverage': 68.4, 'total_snaps': 281}
# {'position': 'LB', 'unit': 'defense', 'week': 4, 'player_id': 138052, 'season': 2020, 'run_defense_snaps': 16, 'run_defense': 86.0, 'player': 'Marvin Pierre', 'pass_rush_snaps': 7, 'pass_rush': 69.6, 'discipline': 79.1, 'defense': 75.7, 'coverage_snaps': 20, 'coverage': 59.3, 'total_snaps': 43}
# {'position': 'CB', 'unit': 'defense', 'week': 4, 'player_id': 104234, 'season': 2020, 'run_defense_snaps': 96, 'run_defense_rank': 58, 'run_defense': 70.4, 'player': 'JT Thompson', 'discipline': 80.6, 'defense_rank': 18, 'defense': 76.7, 'coverage_snaps': 87, 'coverage_rank': 20, 'coverage': 77.0, 'total_snaps': 188}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 87665, 'season': 2020, 'run_block_snaps': 36, 'run_block': 62.1, 'receiving_snaps': 42, 'receiving': 57.0, 'player': 'Michael Jefferson', 'offense': 57.5, 'discipline': 78.4, 'total_snaps': 78}
# {'position': 'ED', 'unit': 'defense', 'week': 4, 'player_id': 76902, 'season': 2020, 'run_defense_snaps': 39, 'run_defense_rank': 67, 'run_defense': 67.3, 'player': 'Randy Charlton', 'pass_rush_snaps': 39, 'pass_rush_rank': 17, 'pass_rush': 84.3, 'discipline': 79.5, 'defense_rank': 32, 'defense': 76.5, 'coverage_snaps': 1, 'coverage': 55.3, 'total_snaps': 86}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 41966, 'season': 2020, 'run_block_snaps': 54, 'run_block': 70.2, 'receiving_snaps': 79, 'receiving_rank': 124, 'receiving': 62.7, 'player': 'Devaughn Cooper', 'offense_rank': 124, 'offense': 62.8, 'discipline': 10.6, 'total_snaps': 133}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 55283, 'season': 2020, 'run_block_snaps': 19, 'run_block': 46.4, 'receiving_snaps': 45, 'receiving': 76.3, 'player': 'Keith Pearson', 'offense': 75.4, 'discipline': 79.2, 'total_snaps': 64}
# {'position': 'CB', 'unit': 'defense', 'week': 4, 'player_id': 89160, 'season': 2020, 'run_defense_snaps': 74, 'run_defense_rank': 149, 'run_defense': 59.1, 'player': 'Cory McCoy', 'pass_rush_snaps': 2, 'pass_rush': 59.0, 'discipline': 82.8, 'defense_rank': 85, 'defense': 68.1, 'coverage_snaps': 120, 'coverage_rank': 58, 'coverage': 70.1, 'total_snaps': 196}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 97867, 'season': 2020, 'run_block_snaps': 56, 'run_block': 65.1, 'receiving_snaps': 37, 'receiving': 72.1, 'player': 'Broc Thompson', 'offense_rank': 35, 'offense': 72.8, 'discipline': 80.8, 'total_snaps': 93}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 78784, 'season': 2020, 'run_block_snaps': 10, 'run_block': 59.4, 'receiving_snaps': 16, 'receiving': 56.8, 'player': 'Levar Gumms', 'offense': 56.7, 'discipline': 75.3, 'total_snaps': 26}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 121707, 'season': 2020, 'run_block_snaps': 18, 'run_block': 74.1, 'receiving_snaps': 85, 'receiving_rank': 87, 'receiving': 65.8, 'player': 'Josh Sterns', 'offense_rank': 84, 'offense': 67.1, 'discipline': 79.3, 'total_snaps': 103}
# {'position': 'ED', 'unit': 'defense', 'week': 4, 'player_id': 56490, 'season': 2020, 'run_defense_snaps': 81, 'run_defense_rank': 71, 'run_defense': 66.6, 'player': 'Antoine Cook', 'pass_rush_snaps': 47, 'pass_rush_rank': 266, 'pass_rush': 52.2, 'discipline': 81.2, 'defense_rank': 131, 'defense': 61.7, 'coverage_snaps': 4, 'coverage': 56.6, 'total_snaps': 161}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 64309, 'season': 2020, 'run_block_snaps': 67, 'run_block_rank': 2, 'run_block': 83.4, 'receiving_snaps': 67, 'receiving_rank': 43, 'receiving': 70.6, 'player': 'Daylen Baldwin', 'offense_rank': 27, 'offense': 73.9, 'discipline': 80.2, 'total_snaps': 134}
# {'position': 'LB', 'unit': 'defense', 'week': 4, 'player_id': 79466, 'season': 2020, 'run_defense_snaps': 17, 'run_defense': 78.0, 'player': 'Bryson Armstrong', 'pass_rush_snaps': 4, 'pass_rush': 56.9, 'discipline': 77.6, 'defense': 72.1, 'coverage_snaps': 16, 'coverage': 67.8, 'total_snaps': 37}
# {'position': 'LB', 'unit': 'defense', 'week': 4, 'player_id': 57662, 'season': 2020, 'run_defense_snaps': 22, 'run_defense': 62.9, 'player': 'Jack Gibbens', 'pass_rush_snaps': 3, 'pass_rush': 64.5, 'discipline': 73.7, 'defense': 65.6, 'coverage_snaps': 23, 'coverage': 64.0, 'total_snaps': 55}
# {'position': 'WR', 'unit': 'offense', 'week': 4, 'player_id': 84427, 'season': 2020, 'run_block_snaps': 41, 'run_block': 58.8, 'receiving_snaps': 69, 'receiving_rank': 117, 'receiving': 63.4, 'player': 'Remi Simmons', 'offense_rank': 116, 'offense': 63.6, 'discipline': 79.5, 'total_snaps': 128}
# {'position': 'CB', 'unit': 'defense', 'week': 0, 'player_id': 121345, 'season': 2020, 'run_block_snaps': 1, 'run_block_rank': 1, 'run_block': 60.0, 'player': 'Elijah Culp', 'offense_rank': 1, 'offense': 60.0, 'total_snaps': 1}
# {'position': 'ED', 'unit': 'defense', 'week': 10, 'player_id': 56862, 'season': 2020, 'run_defense_snaps': 164, 'run_defense_rank': 109, 'run_defense': 70.7, 'player': 'Arnold Ebiketie', 'pass_rush_snaps': 126, 'pass_rush_rank': 20, 'pass_rush': 86.7, 'discipline': 59.2, 'defense_rank': 44, 'defense': 80.4, 'coverage_snaps': 6, 'coverage': 62.2, 'total_snaps': 378}
# {'position': 'WR', 'unit': 'offense', 'run': 59.9, 'week': 10, 'player_id': 102929, 'season': 2020, 'run_snaps': 3, 'run_block_snaps': 85, 'run_block': 40.2, 'receiving_snaps': 259, 'receiving_rank': 209, 'receiving': 67.6, 'player': 'Kaylon Geiger', 'offense_rank': 188, 'offense': 65.6, 'discipline': 86.9, 'total_snaps': 367}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 65081, 'season': 2020, 'run_defense_snaps': 87, 'run_defense_rank': 117, 'run_defense': 74.2, 'player': 'Allie Green IV', 'discipline': 0.0, 'defense_rank': 510, 'defense': 48.9, 'coverage_snaps': 133, 'coverage_rank': 464, 'coverage': 47.4, 'total_snaps': 233}
# {'position': 'ED', 'unit': 'defense', 'week': 10, 'player_id': 36723, 'season': 2020, 'run_defense_snaps': 129, 'run_defense_rank': 50, 'run_defense': 76.8, 'player': 'Elijah Taylor', 'pass_rush_snaps': 124, 'pass_rush_rank': 291, 'pass_rush': 59.9, 'discipline': 81.4, 'defense_rank': 61, 'defense': 77.9, 'coverage_snaps': 1, 'coverage': 68.7, 'total_snaps': 282}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 97215, 'season': 2020, 'receiving_snaps': 8, 'receiving': 55.4, 'player': 'Lincoln Victor', 'offense': 54.6, 'discipline': 70.2, 'total_snaps': 9}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 136842, 'season': 2020, 'run_defense_snaps': 85, 'run_defense': 58.4, 'player': 'Ridge Texada', 'pass_rush_snaps': 17, 'pass_rush_rank': 54, 'pass_rush': 50.2, 'discipline': 83.5, 'defense_rank': 360, 'defense': 62.5, 'coverage_snaps': 91, 'coverage': 65.6, 'total_snaps': 193}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 41966, 'season': 2020, 'run_block_snaps': 77, 'run_block': 66.9, 'receiving_snaps': 130, 'receiving_rank': 375, 'receiving': 60.3, 'player': 'Devaughn Cooper', 'offense': 60.5, 'discipline': 31.2, 'total_snaps': 207}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 83253, 'season': 2020, 'run_defense_snaps': 25, 'run_defense': 66.5, 'player': 'DJ Johnson', 'discipline': 76.5, 'defense': 59.4, 'coverage_snaps': 18, 'coverage': 56.5, 'total_snaps': 46}
# {'position': 'WR', 'unit': 'offense', 'run': 54.3, 'week': 10, 'player_id': 84427, 'season': 2020, 'run_snaps': 2, 'run_block_snaps': 138, 'run_block': 51.9, 'receiving_snaps': 189, 'receiving_rank': 254, 'receiving': 65.4, 'player': 'Remi Simmons', 'offense_rank': 235, 'offense': 63.1, 'discipline': 47.8, 'total_snaps': 363}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 65033, 'season': 2020, 'run_defense_snaps': 91, 'run_defense_rank': 110, 'run_defense': 74.6, 'player': 'Akayleb Evans', 'discipline': 0.0, 'defense_rank': 337, 'defense': 63.5, 'coverage_snaps': 113, 'coverage_rank': 317, 'coverage': 62.2, 'total_snaps': 218}
# {'position': 'LB', 'unit': 'defense', 'week': 10, 'player_id': 138052, 'season': 2020, 'run_defense_snaps': 70, 'run_defense': 81.9, 'player': 'Marvin Pierre', 'pass_rush_snaps': 24, 'pass_rush': 82.9, 'discipline': 6.7, 'defense_rank': 9, 'defense': 88.4, 'coverage_snaps': 78, 'coverage_rank': 16, 'coverage': 82.9, 'total_snaps': 193}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 89160, 'season': 2020, 'run_defense_snaps': 184, 'run_defense_rank': 65, 'run_defense': 77.7, 'player': 'Cory McCoy', 'pass_rush_snaps': 11, 'pass_rush_rank': 17, 'pass_rush': 66.6, 'discipline': 44.3, 'defense_rank': 138, 'defense': 71.9, 'coverage_snaps': 251, 'coverage_rank': 162, 'coverage': 70.0, 'total_snaps': 446}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 97867, 'season': 2020, 'run_block_snaps': 89, 'run_block': 63.6, 'receiving_snaps': 68, 'receiving': 72.1, 'player': 'Broc Thompson', 'offense': 72.5, 'discipline': 82.7, 'total_snaps': 169}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 21922, 'season': 2020, 'run_defense_snaps': 171, 'run_defense_rank': 34, 'run_defense': 81.4, 'player': 'Mark Williams', 'discipline': 82.0, 'defense_rank': 20, 'defense': 81.2, 'coverage_snaps': 177, 'coverage_rank': 30, 'coverage': 79.7, 'total_snaps': 348}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 102462, 'season': 2020, 'run_defense_snaps': 153, 'run_defense_rank': 137, 'run_defense': 72.7, 'player': 'Tra Fluellen', 'pass_rush_snaps': 5, 'pass_rush': 56.3, 'discipline': 85.1, 'defense_rank': 512, 'defense': 48.1, 'coverage_snaps': 185, 'coverage_rank': 473, 'coverage': 40.4, 'total_snaps': 404}
# {'position': 'ED', 'unit': 'defense', 'week': 10, 'player_id': 76902, 'season': 2020, 'run_defense_snaps': 95, 'run_defense': 72.7, 'player': 'Randy Charlton', 'pass_rush_snaps': 114, 'pass_rush_rank': 69, 'pass_rush': 76.9, 'discipline': 47.6, 'defense_rank': 76, 'defense': 75.5, 'coverage_snaps': 1, 'coverage': 55.3, 'total_snaps': 226}
# {'position': 'LB', 'unit': 'defense', 'week': 10, 'player_id': 57662, 'season': 2020, 'run_defense_snaps': 181, 'run_defense_rank': 202, 'run_defense': 67.2, 'player': 'Jack Gibbens', 'pass_rush_snaps': 11, 'pass_rush': 92.0, 'discipline': 28.5, 'defense_rank': 102, 'defense': 74.5, 'coverage_snaps': 93, 'coverage_rank': 50, 'coverage': 74.2, 'total_snaps': 325}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 87665, 'season': 2020, 'run_block_snaps': 152, 'run_block': 71.7, 'receiving_snaps': 223, 'receiving_rank': 289, 'receiving': 64.0, 'player': 'Michael Jefferson', 'offense_rank': 198, 'offense': 65.3, 'discipline': 84.1, 'total_snaps': 375}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 56122, 'season': 2020, 'run_defense_snaps': 179, 'run_defense_rank': 338, 'run_defense': 58.1, 'player': 'Cam Johnson', 'discipline': 28.8, 'defense_rank': 162, 'defense': 70.7, 'coverage_snaps': 202, 'coverage_rank': 82, 'coverage': 74.7, 'total_snaps': 419}
# {'position': 'LB', 'unit': 'defense', 'week': 10, 'player_id': 42679, 'season': 2020, 'run_defense_snaps': 78, 'run_defense': 62.8, 'player': 'Isaiah Graham-Mobley', 'pass_rush_snaps': 4, 'pass_rush': 66.6, 'discipline': 0.0, 'defense': 60.9, 'coverage_snaps': 24, 'coverage': 60.3, 'total_snaps': 119}
# {'position': 'WR', 'unit': 'offense', 'pass': 49.9, 'week': 10, 'player_id': 55283, 'season': 2020, 'run_block_snaps': 167, 'run_block_rank': 84, 'run_block': 53.4, 'receiving_snaps': 289, 'receiving_rank': 17, 'receiving': 84.3, 'player': 'Keith Pearson', 'pass_snaps': 1, 'pass_block_snaps': 1, 'pass_block': 62.6, 'offense_rank': 14, 'offense': 82.5, 'discipline': 87.3, 'total_snaps': 459}
# {'position': 'LB', 'unit': 'defense', 'week': 10, 'player_id': 57759, 'season': 2020, 'run_defense_snaps': 45, 'run_defense': 54.4, 'player': 'Jerry Roberts', 'pass_rush_snaps': 9, 'pass_rush': 56.5, 'discipline': 80.7, 'defense': 60.7, 'coverage_snaps': 22, 'coverage': 67.8, 'total_snaps': 85}
# {'position': 'WR', 'unit': 'offense', 'run': 59.5, 'week': 10, 'player_id': 97288, 'season': 2020, 'run_snaps': 1, 'run_block_snaps': 122, 'run_block': 66.2, 'receiving_snaps': 249, 'receiving_rank': 261, 'receiving': 64.9, 'player': 'Tahj Washington', 'offense_rank': 201, 'offense': 65.1, 'discipline': 54.1, 'total_snaps': 452}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 121707, 'season': 2020, 'run_block_snaps': 35, 'run_block': 51.0, 'receiving_snaps': 118, 'receiving_rank': 249, 'receiving': 65.6, 'player': 'Josh Sterns', 'offense': 65.0, 'discipline': 80.6, 'total_snaps': 153}
# {'position': 'ED', 'unit': 'defense', 'week': 10, 'player_id': 82430, 'season': 2020, 'run_defense_snaps': 2, 'run_defense': 63.0, 'player': 'Mohamed Diallo', 'pass_rush_snaps': 1, 'pass_rush': 60.0, 'discipline': 67.7, 'defense': 69.0, 'total_snaps': 3}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 104234, 'season': 2020, 'run_defense_snaps': 275, 'run_defense_rank': 46, 'run_defense': 80.0, 'player': 'JT Thompson', 'pass_rush_snaps': 6, 'pass_rush': 62.6, 'discipline': 37.8, 'defense_rank': 260, 'defense': 66.6, 'coverage_snaps': 235, 'coverage_rank': 291, 'coverage': 63.7, 'total_snaps': 525}
# {'position': 'ED', 'unit': 'defense', 'week': 10, 'player_id': 55198, 'season': 2020, 'run_defense_snaps': 117, 'run_defense_rank': 74, 'run_defense': 74.4, 'player': 'Jordan Strachan', 'pass_rush_snaps': 157, 'pass_rush_rank': 27, 'pass_rush': 83.7, 'discipline': 34.5, 'defense_rank': 121, 'defense': 72.2, 'coverage_snaps': 73, 'coverage_rank': 67, 'coverage': 49.0, 'total_snaps': 373}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 102599, 'season': 2020, 'run_block_snaps': 79, 'run_block': 72.1, 'receiving_snaps': 242, 'receiving_rank': 149, 'receiving': 70.3, 'player': 'Ben Ratzlaff', 'pass_block_snaps': 1, 'pass_block': 62.1, 'offense_rank': 120, 'offense': 69.9, 'discipline': 0.0, 'total_snaps': 322}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 97287, 'season': 2020, 'run_block_snaps': 6, 'run_block': 58.6, 'receiving_snaps': 3, 'receiving': 58.5, 'player': 'Trevor Wilson', 'offense': 50.3, 'discipline': 0.0, 'total_snaps': 9}
# {'position': 'WR', 'unit': 'offense', 'run': 60.3, 'pass': 46.8, 'week': 10, 'player_id': 102597, 'season': 2020, 'run_snaps': 1, 'run_block_snaps': 68, 'run_block': 60.7, 'receiving_snaps': 230, 'receiving_rank': 44, 'receiving': 78.8, 'player': 'Jerreth Sterns', 'pass_snaps': 1, 'offense_rank': 36, 'offense': 78.3, 'discipline': 86.6, 'total_snaps': 321}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 78784, 'season': 2020, 'run_block_snaps': 106, 'run_block': 55.6, 'receiving_snaps': 193, 'receiving_rank': 508, 'receiving': 54.8, 'player': 'Levar Gumms', 'offense_rank': 367, 'offense': 54.9, 'discipline': 84.8, 'total_snaps': 299}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 64309, 'season': 2020, 'run_block_snaps': 177, 'run_block_rank': 1, 'run_block': 82.1, 'receiving_snaps': 262, 'receiving_rank': 110, 'receiving': 72.4, 'player': 'Daylen Baldwin', 'offense_rank': 62, 'offense': 74.5, 'discipline': 84.6, 'total_snaps': 439}
# {'position': 'LB', 'unit': 'defense', 'week': 10, 'player_id': 97709, 'season': 2020, 'run_defense_snaps': 21, 'run_defense': 61.9, 'player': 'Rich Miller', 'pass_rush_snaps': 1, 'pass_rush': 69.7, 'discipline': 76.2, 'defense': 68.2, 'coverage_snaps': 16, 'coverage': 65.4, 'total_snaps': 61}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 97890, 'season': 2020, 'run_defense_snaps': 7, 'run_defense': 57.4, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'David Spaulding', 'offense': 60.0, 'discipline': 71.5, 'defense': 42.8, 'coverage_snaps': 5, 'coverage': 53.1, 'total_snaps': 29}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 63672, 'season': 2020, 'run_block_snaps': 22, 'run_block': 59.6, 'receiving_snaps': 30, 'receiving': 56.7, 'player': 'Bryce Nunnelly', 'offense': 57.0, 'discipline': 77.0, 'total_snaps': 56}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 76681, 'season': 2020, 'run_defense_snaps': 253, 'run_defense_rank': 200, 'run_defense': 68.7, 'player': 'Jeremy Webb', 'pass_rush_snaps': 0, 'pass_rush': 60.0, 'discipline': 5.3, 'defense_rank': 96, 'defense': 73.9, 'coverage_snaps': 313, 'coverage_rank': 79, 'coverage': 75.0, 'total_snaps': 637}
# {'position': 'WR', 'unit': 'offense', 'run': 60.8, 'pass': 87.3, 'week': 10, 'player_id': 38411, 'season': 2020, 'run_snaps': 2, 'run_block_snaps': 4, 'run_block': 39.3, 'receiving_snaps': 32, 'receiving': 55.6, 'player': 'Melquise Stovall', 'pass_snaps': 1, 'pass_block_snaps': 3, 'pass_block': 19.6, 'offense': 58.4, 'discipline': 77.8, 'total_snaps': 67}
# {'position': 'LB', 'unit': 'defense', 'week': 10, 'player_id': 58293, 'season': 2020, 'run_defense_snaps': 21, 'run_defense': 39.8, 'player': 'Treshaun Hayward', 'pass_rush_snaps': 11, 'pass_rush': 64.3, 'discipline': 0.0, 'defense': 36.8, 'coverage_snaps': 21, 'coverage': 43.4, 'total_snaps': 56}
# {'position': 'ED', 'unit': 'defense', 'week': 10, 'player_id': 56490, 'season': 2020, 'run_defense_snaps': 81, 'run_defense': 66.6, 'player': 'Antoine Cook', 'pass_rush_snaps': 47, 'pass_rush': 52.2, 'discipline': 81.2, 'defense': 61.7, 'coverage_snaps': 4, 'coverage': 56.6, 'total_snaps': 161}
# {'position': 'CB', 'unit': 'defense', 'week': 10, 'player_id': 121345, 'season': 2020, 'run_defense_snaps': 185, 'run_defense_rank': 46, 'run_defense': 80.0, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'Elijah Culp', 'pass_rush_snaps': 1, 'pass_rush': 60.0, 'offense': 60.0, 'discipline': 83.1, 'defense_rank': 13, 'defense': 83.0, 'coverage_snaps': 172, 'coverage_rank': 11, 'coverage': 82.4, 'total_snaps': 431}
# {'position': 'WR', 'unit': 'offense', 'run': 63.5, 'week': 10, 'player_id': 102544, 'season': 2020, 'run_snaps': 1, 'run_block_snaps': 84, 'run_block': 84.9, 'receiving_snaps': 147, 'receiving_rank': 150, 'receiving': 70.2, 'player': 'Brandon Sanders', 'offense_rank': 79, 'offense': 73.1, 'discipline': 84.1, 'total_snaps': 233}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 84317, 'season': 2020, 'run_block_snaps': 152, 'run_block': 63.3, 'receiving_snaps': 177, 'receiving_rank': 196, 'receiving': 68.2, 'player': 'Harry Ballard III', 'pass_block_snaps': 1, 'pass_block': 61.9, 'offense_rank': 137, 'offense': 68.8, 'discipline': 87.9, 'total_snaps': 330}
# {'position': 'LB', 'unit': 'defense', 'week': 10, 'player_id': 79466, 'season': 2020, 'run_defense_snaps': 117, 'run_defense_rank': 136, 'run_defense': 73.0, 'player': 'Bryson Armstrong', 'pass_rush_snaps': 30, 'pass_rush': 76.9, 'discipline': 83.6, 'defense_rank': 69, 'defense': 77.1, 'coverage_snaps': 115, 'coverage_rank': 49, 'coverage': 74.3, 'total_snaps': 262}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 42095, 'season': 2020, 'run_block_snaps': 41, 'run_block': 50.1, 'receiving_snaps': 47, 'receiving': 59.1, 'player': 'Jahcour Pearson', 'offense': 58.0, 'discipline': 77.8, 'total_snaps': 88}
# {'position': 'WR', 'unit': 'offense', 'week': 10, 'player_id': 89497, 'season': 2020, 'run_block_snaps': 112, 'run_block': 56.6, 'receiving_snaps': 130, 'receiving_rank': 66, 'receiving': 75.5, 'player': 'Izaiah Gathings', 'pass_block_snaps': 1, 'pass_block': 61.9, 'offense_rank': 58, 'offense': 75.0, 'discipline': 84.0, 'total_snaps': 243}
# {'position': 'LB', 'unit': 'defense', 'week': 10, 'player_id': 63327, 'season': 2020, 'run_defense_snaps': 106, 'run_defense_rank': 246, 'run_defense': 63.6, 'player': 'Zack Woodard', 'pass_rush_snaps': 18, 'pass_rush': 55.7, 'discipline': 79.4, 'defense_rank': 120, 'defense': 73.2, 'coverage_snaps': 131, 'coverage_rank': 18, 'coverage': 81.4, 'total_snaps': 288}
# {'position': 'LB', 'unit': 'defense', 'week': 10, 'player_id': 75826, 'season': 2020, 'run_defense_snaps': 62, 'run_defense': 57.1, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'Blaze Alldredge', 'pass_rush_snaps': 18, 'pass_rush': 68.3, 'offense': 60.0, 'discipline': 0.0, 'defense': 51.4, 'coverage_snaps': 47, 'coverage': 46.8, 'total_snaps': 134}
# {'position': 'CB', 'unit': 'defense', 'week': 7, 'player_id': 102462, 'season': 2020, 'run_defense_snaps': 153, 'run_defense_rank': 89, 'run_defense': 72.7, 'player': 'Tra Fluellen', 'pass_rush_snaps': 5, 'pass_rush': 56.3, 'discipline': 85.1, 'defense_rank': 420, 'defense': 48.1, 'coverage_snaps': 185, 'coverage_rank': 395, 'coverage': 40.4, 'total_snaps': 404}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 87665, 'season': 2020, 'run_block_snaps': 75, 'run_block': 63.9, 'receiving_snaps': 106, 'receiving_rank': 256, 'receiving': 61.9, 'player': 'Michael Jefferson', 'offense_rank': 202, 'offense': 62.5, 'discipline': 81.3, 'total_snaps': 181}
# {'position': 'LB', 'unit': 'defense', 'week': 7, 'player_id': 63327, 'season': 2020, 'run_defense_snaps': 91, 'run_defense_rank': 194, 'run_defense': 61.4, 'player': 'Zack Woodard', 'pass_rush_snaps': 17, 'pass_rush': 56.0, 'discipline': 79.3, 'defense_rank': 64, 'defense': 74.7, 'coverage_snaps': 121, 'coverage_rank': 5, 'coverage': 85.2, 'total_snaps': 259}
# {'position': 'CB', 'unit': 'defense', 'week': 7, 'player_id': 97890, 'season': 2020, 'run_defense_snaps': 4, 'run_defense': 60.0, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'David Spaulding', 'offense': 60.0, 'discipline': 68.4, 'defense': 46.8, 'coverage_snaps': 1, 'coverage': 60.0, 'total_snaps': 16}
# {'position': 'CB', 'unit': 'defense', 'week': 7, 'player_id': 56122, 'season': 2020, 'run_defense_snaps': 179, 'run_defense_rank': 267, 'run_defense': 58.1, 'player': 'Cam Johnson', 'discipline': 28.8, 'defense_rank': 113, 'defense': 70.7, 'coverage_snaps': 202, 'coverage_rank': 61, 'coverage': 74.7, 'total_snaps': 419}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 42095, 'season': 2020, 'run_block_snaps': 41, 'run_block': 50.1, 'receiving_snaps': 47, 'receiving': 59.1, 'player': 'Jahcour Pearson', 'offense': 58.0, 'discipline': 77.8, 'total_snaps': 88}
# {'position': 'ED', 'unit': 'defense', 'week': 7, 'player_id': 36723, 'season': 2020, 'run_defense_snaps': 92, 'run_defense_rank': 46, 'run_defense': 74.1, 'player': 'Elijah Taylor', 'pass_rush_snaps': 68, 'pass_rush_rank': 285, 'pass_rush': 57.0, 'discipline': 79.4, 'defense_rank': 43, 'defense': 77.7, 'coverage_snaps': 0, 'coverage': 67.9, 'total_snaps': 181}
# {'position': 'CB', 'unit': 'defense', 'week': 7, 'player_id': 65033, 'season': 2020, 'run_defense_snaps': 67, 'run_defense_rank': 312, 'run_defense': 52.2, 'player': 'Akayleb Evans', 'discipline': 0.0, 'defense_rank': 369, 'defense': 55.7, 'coverage_snaps': 79, 'coverage_rank': 303, 'coverage': 58.4, 'total_snaps': 156}
# {'position': 'WR', 'unit': 'offense', 'pass': 49.9, 'week': 7, 'player_id': 55283, 'season': 2020, 'run_block_snaps': 89, 'run_block': 50.9, 'receiving_snaps': 167, 'receiving_rank': 45, 'receiving': 76.8, 'player': 'Keith Pearson', 'pass_snaps': 1, 'offense_rank': 45, 'offense': 75.0, 'discipline': 85.0, 'total_snaps': 258}
# {'position': 'WR', 'unit': 'offense', 'run': 60.3, 'pass': 46.8, 'week': 7, 'player_id': 102597, 'season': 2020, 'run_snaps': 1, 'run_block_snaps': 68, 'run_block': 60.7, 'receiving_snaps': 230, 'receiving_rank': 30, 'receiving': 78.8, 'player': 'Jerreth Sterns', 'pass_snaps': 1, 'offense_rank': 28, 'offense': 78.3, 'discipline': 86.6, 'total_snaps': 321}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 97867, 'season': 2020, 'run_block_snaps': 89, 'run_block': 63.6, 'receiving_snaps': 68, 'receiving': 72.1, 'player': 'Broc Thompson', 'offense_rank': 62, 'offense': 72.5, 'discipline': 82.7, 'total_snaps': 169}
# {'position': 'WR', 'unit': 'offense', 'run': 60.8, 'week': 7, 'player_id': 102929, 'season': 2020, 'run_snaps': 2, 'run_block_snaps': 57, 'run_block': 31.1, 'receiving_snaps': 136, 'receiving_rank': 167, 'receiving': 65.8, 'player': 'Kaylon Geiger', 'offense_rank': 208, 'offense': 62.1, 'discipline': 84.0, 'total_snaps': 204}
# {'position': 'CB', 'unit': 'defense', 'week': 7, 'player_id': 136842, 'season': 2020, 'run_defense_snaps': 74, 'run_defense_rank': 276, 'run_defense': 57.4, 'player': 'Ridge Texada', 'pass_rush_snaps': 16, 'pass_rush_rank': 62, 'pass_rush': 50.0, 'discipline': 82.5, 'defense_rank': 301, 'defense': 60.8, 'coverage_snaps': 75, 'coverage_rank': 227, 'coverage': 63.9, 'total_snaps': 165}
# {'position': 'LB', 'unit': 'defense', 'week': 7, 'player_id': 57662, 'season': 2020, 'run_defense_snaps': 54, 'run_defense': 69.0, 'player': 'Jack Gibbens', 'pass_rush_snaps': 3, 'pass_rush': 64.5, 'discipline': 76.2, 'defense': 69.2, 'coverage_snaps': 29, 'coverage': 65.1, 'total_snaps': 104}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 64309, 'season': 2020, 'run_block_snaps': 136, 'run_block_rank': 2, 'run_block': 85.2, 'receiving_snaps': 169, 'receiving_rank': 107, 'receiving': 70.2, 'player': 'Daylen Baldwin', 'offense_rank': 59, 'offense': 72.9, 'discipline': 83.2, 'total_snaps': 305}
# {'position': 'LB', 'unit': 'defense', 'week': 7, 'player_id': 42679, 'season': 2020, 'run_defense_snaps': 78, 'run_defense_rank': 181, 'run_defense': 62.8, 'player': 'Isaiah Graham-Mobley', 'pass_rush_snaps': 4, 'pass_rush': 66.6, 'discipline': 0.0, 'defense': 60.9, 'coverage_snaps': 24, 'coverage': 60.3, 'total_snaps': 119}
# {'position': 'CB', 'unit': 'defense', 'week': 7, 'player_id': 65081, 'season': 2020, 'run_defense_snaps': 40, 'run_defense': 66.6, 'player': 'Allie Green IV', 'discipline': 78.4, 'defense': 49.8, 'coverage_snaps': 52, 'coverage': 46.8, 'total_snaps': 98}
# {'position': 'LB', 'unit': 'defense', 'week': 7, 'player_id': 138052, 'season': 2020, 'run_defense_snaps': 47, 'run_defense': 87.0, 'player': 'Marvin Pierre', 'pass_rush_snaps': 22, 'pass_rush': 76.5, 'discipline': 0.0, 'defense': 87.7, 'coverage_snaps': 58, 'coverage': 80.8, 'total_snaps': 127}
# {'position': 'CB', 'unit': 'defense', 'week': 7, 'player_id': 76681, 'season': 2020, 'run_defense_snaps': 217, 'run_defense_rank': 205, 'run_defense': 65.0, 'player': 'Jeremy Webb', 'pass_rush_snaps': 0, 'pass_rush': 60.0, 'discipline': 0.0, 'defense_rank': 94, 'defense': 72.1, 'coverage_snaps': 285, 'coverage_rank': 72, 'coverage': 73.6, 'total_snaps': 561}
# {'position': 'ED', 'unit': 'defense', 'week': 7, 'player_id': 56862, 'season': 2020, 'run_defense_snaps': 86, 'run_defense_rank': 51, 'run_defense': 73.3, 'player': 'Arnold Ebiketie', 'pass_rush_snaps': 33, 'pass_rush': 85.7, 'discipline': 83.5, 'defense': 81.7, 'coverage_snaps': 1, 'coverage': 61.0, 'total_snaps': 152}
# {'position': 'ED', 'unit': 'defense', 'week': 7, 'player_id': 56490, 'season': 2020, 'run_defense_snaps': 81, 'run_defense_rank': 115, 'run_defense': 66.6, 'player': 'Antoine Cook', 'pass_rush_snaps': 47, 'pass_rush': 52.2, 'discipline': 81.2, 'defense_rank': 221, 'defense': 61.7, 'coverage_snaps': 4, 'coverage': 56.6, 'total_snaps': 161}
# {'position': 'CB', 'unit': 'defense', 'week': 7, 'player_id': 121345, 'season': 2020, 'run_defense_snaps': 149, 'run_defense_rank': 40, 'run_defense': 78.2, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'Elijah Culp', 'pass_rush_snaps': 1, 'pass_rush': 60.0, 'offense': 60.0, 'discipline': 82.5, 'defense_rank': 5, 'defense': 85.5, 'coverage_snaps': 151, 'coverage_rank': 5, 'coverage': 86.0, 'total_snaps': 366}
# {'position': 'WR', 'unit': 'offense', 'run': 57.5, 'week': 7, 'player_id': 84427, 'season': 2020, 'run_snaps': 1, 'run_block_snaps': 73, 'run_block': 47.3, 'receiving_snaps': 114, 'receiving_rank': 278, 'receiving': 60.8, 'player': 'Remi Simmons', 'offense_rank': 256, 'offense': 59.2, 'discipline': 81.6, 'total_snaps': 212}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 121707, 'season': 2020, 'run_block_snaps': 35, 'run_block': 51.0, 'receiving_snaps': 118, 'receiving_rank': 170, 'receiving': 65.6, 'player': 'Josh Sterns', 'offense': 65.0, 'discipline': 80.6, 'total_snaps': 153}
# {'position': 'CB', 'unit': 'defense', 'week': 7, 'player_id': 89160, 'season': 2020, 'run_defense_snaps': 124, 'run_defense_rank': 82, 'run_defense': 73.3, 'player': 'Cory McCoy', 'pass_rush_snaps': 8, 'pass_rush_rank': 14, 'pass_rush': 69.3, 'discipline': 85.5, 'defense_rank': 73, 'defense': 73.6, 'coverage_snaps': 164, 'coverage_rank': 90, 'coverage': 72.3, 'total_snaps': 296}
# {'position': 'ED', 'unit': 'defense', 'week': 7, 'player_id': 55198, 'season': 2020, 'run_defense_snaps': 66, 'run_defense': 73.5, 'player': 'Jordan Strachan', 'pass_rush_snaps': 94, 'pass_rush_rank': 55, 'pass_rush': 76.5, 'discipline': 43.8, 'defense_rank': 127, 'defense': 69.6, 'coverage_snaps': 33, 'coverage_rank': 66, 'coverage': 47.6, 'total_snaps': 207}
# {'position': 'CB', 'unit': 'defense', 'week': 7, 'player_id': 104234, 'season': 2020, 'run_defense_snaps': 203, 'run_defense_rank': 65, 'run_defense': 75.4, 'player': 'JT Thompson', 'discipline': 23.4, 'defense_rank': 253, 'defense': 64.1, 'coverage_snaps': 169, 'coverage_rank': 247, 'coverage': 62.3, 'total_snaps': 377}
# {'position': 'ED', 'unit': 'defense', 'week': 7, 'player_id': 76902, 'season': 2020, 'run_defense_snaps': 78, 'run_defense_rank': 54, 'run_defense': 72.9, 'player': 'Randy Charlton', 'pass_rush_snaps': 95, 'pass_rush_rank': 72, 'pass_rush': 74.3, 'discipline': 41.0, 'defense_rank': 81, 'defense': 73.6, 'coverage_snaps': 1, 'coverage': 55.3, 'total_snaps': 188}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 78784, 'season': 2020, 'run_block_snaps': 73, 'run_block': 53.1, 'receiving_snaps': 102, 'receiving_rank': 411, 'receiving': 54.2, 'player': 'Levar Gumms', 'offense_rank': 320, 'offense': 54.0, 'discipline': 82.6, 'total_snaps': 175}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 97288, 'season': 2020, 'run_block_snaps': 56, 'run_block': 69.3, 'receiving_snaps': 115, 'receiving_rank': 301, 'receiving': 59.8, 'player': 'Tahj Washington', 'offense_rank': 234, 'offense': 60.3, 'discipline': 23.5, 'total_snaps': 208}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 102599, 'season': 2020, 'run_block_snaps': 79, 'run_block': 72.1, 'receiving_snaps': 242, 'receiving_rank': 103, 'receiving': 70.3, 'player': 'Ben Ratzlaff', 'pass_block_snaps': 1, 'pass_block': 62.1, 'offense_rank': 94, 'offense': 69.9, 'discipline': 0.0, 'total_snaps': 322}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 84317, 'season': 2020, 'run_block_snaps': 78, 'run_block': 62.9, 'receiving_snaps': 89, 'receiving_rank': 92, 'receiving': 70.9, 'player': 'Harry Ballard III', 'pass_block_snaps': 1, 'pass_block': 61.9, 'offense_rank': 73, 'offense': 71.5, 'discipline': 84.8, 'total_snaps': 168}
# {'position': 'CB', 'unit': 'defense', 'week': 7, 'player_id': 21922, 'season': 2020, 'run_defense_snaps': 136, 'run_defense_rank': 46, 'run_defense': 77.3, 'player': 'Mark Williams', 'discipline': 81.2, 'defense_rank': 11, 'defense': 81.7, 'coverage_snaps': 152, 'coverage_rank': 12, 'coverage': 81.3, 'total_snaps': 288}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 102544, 'season': 2020, 'run_block_snaps': 14, 'run_block': 88.0, 'receiving_snaps': 41, 'receiving': 88.3, 'player': 'Brandon Sanders', 'offense': 90.5, 'discipline': 78.2, 'total_snaps': 55}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 89497, 'season': 2020, 'run_block_snaps': 56, 'run_block': 57.9, 'receiving_snaps': 54, 'receiving': 85.4, 'player': 'Izaiah Gathings', 'pass_block_snaps': 1, 'pass_block': 61.9, 'offense': 85.0, 'discipline': 80.9, 'total_snaps': 111}
# {'position': 'WR', 'unit': 'offense', 'week': 7, 'player_id': 41966, 'season': 2020, 'run_block_snaps': 66, 'run_block': 68.5, 'receiving_snaps': 106, 'receiving_rank': 238, 'receiving': 62.8, 'player': 'Devaughn Cooper', 'offense_rank': 189, 'offense': 63.0, 'discipline': 22.9, 'total_snaps': 172}
# {'position': 'LB', 'unit': 'defense', 'week': 7, 'player_id': 79466, 'season': 2020, 'run_defense_snaps': 57, 'run_defense': 75.6, 'player': 'Bryson Armstrong', 'pass_rush_snaps': 15, 'pass_rush': 74.8, 'discipline': 81.7, 'defense_rank': 72, 'defense': 74.1, 'coverage_snaps': 84, 'coverage_rank': 70, 'coverage': 69.0, 'total_snaps': 156}
# {'position': 'WR', 'unit': 'offense', 'week': 9, 'player_id': 64309, 'season': 2020, 'run_block_snaps': 177, 'run_block_rank': 3, 'run_block': 82.1, 'receiving_snaps': 262, 'receiving_rank': 97, 'receiving': 72.4, 'player': 'Daylen Baldwin', 'offense_rank': 58, 'offense': 74.5, 'discipline': 84.6, 'total_snaps': 439}
# {'position': 'WR', 'unit': 'offense', 'run': 63.1, 'week': 9, 'player_id': 38411, 'season': 2020, 'run_snaps': 1, 'run_block_snaps': 2, 'run_block': 60.0, 'receiving_snaps': 14, 'receiving': 69.2, 'player': 'Melquise Stovall', 'pass_block_snaps': 1, 'pass_block': 0.0, 'offense': 69.0, 'discipline': 75.5, 'total_snaps': 33}
# {'position': 'WR', 'unit': 'offense', 'week': 9, 'player_id': 87665, 'season': 2020, 'run_block_snaps': 122, 'run_block': 73.0, 'receiving_snaps': 192, 'receiving_rank': 293, 'receiving': 62.9, 'player': 'Michael Jefferson', 'offense_rank': 194, 'offense': 64.3, 'discipline': 83.4, 'total_snaps': 314}
# {'position': 'ED', 'unit': 'defense', 'week': 9, 'player_id': 56862, 'season': 2020, 'run_defense_snaps': 144, 'run_defense_rank': 82, 'run_defense': 71.7, 'player': 'Arnold Ebiketie', 'pass_rush_snaps': 89, 'pass_rush_rank': 14, 'pass_rush': 87.6, 'discipline': 53.0, 'defense_rank': 42, 'defense': 79.3, 'coverage_snaps': 5, 'coverage': 52.7, 'total_snaps': 302}
# {'position': 'WR', 'unit': 'offense', 'run': 60.3, 'pass': 46.8, 'week': 9, 'player_id': 102597, 'season': 2020, 'run_snaps': 1, 'run_block_snaps': 68, 'run_block': 60.7, 'receiving_snaps': 230, 'receiving_rank': 38, 'receiving': 78.8, 'player': 'Jerreth Sterns', 'pass_snaps': 1, 'offense_rank': 31, 'offense': 78.3, 'discipline': 86.6, 'total_snaps': 321}
# {'position': 'LB', 'unit': 'defense', 'week': 9, 'player_id': 57662, 'season': 2020, 'run_defense_snaps': 128, 'run_defense_rank': 84, 'run_defense': 77.5, 'player': 'Jack Gibbens', 'pass_rush_snaps': 8, 'pass_rush': 66.4, 'discipline': 16.7, 'defense_rank': 93, 'defense': 73.7, 'coverage_snaps': 72, 'coverage': 68.1, 'total_snaps': 240}
# {'position': 'CB', 'unit': 'defense', 'week': 9, 'player_id': 136842, 'season': 2020, 'run_defense_snaps': 85, 'run_defense_rank': 318, 'run_defense': 58.4, 'player': 'Ridge Texada', 'pass_rush_snaps': 17, 'pass_rush_rank': 48, 'pass_rush': 50.2, 'discipline': 83.5, 'defense_rank': 322, 'defense': 62.5, 'coverage_snaps': 91, 'coverage': 65.6, 'total_snaps': 193}
# {'position': 'WR', 'unit': 'offense', 'week': 9, 'player_id': 89497, 'season': 2020, 'run_block_snaps': 84, 'run_block': 58.6, 'receiving_snaps': 97, 'receiving_rank': 42, 'receiving': 78.5, 'player': 'Izaiah Gathings', 'pass_block_snaps': 1, 'pass_block': 61.9, 'offense': 78.3, 'discipline': 82.9, 'total_snaps': 182}
# {'position': 'WR', 'unit': 'offense', 'week': 9, 'player_id': 102599, 'season': 2020, 'run_block_snaps': 79, 'run_block': 72.1, 'receiving_snaps': 242, 'receiving_rank': 140, 'receiving': 70.3, 'player': 'Ben Ratzlaff', 'pass_block_snaps': 1, 'pass_block': 62.1, 'offense_rank': 111, 'offense': 69.9, 'discipline': 0.0, 'total_snaps': 322}
# {'position': 'WR', 'unit': 'offense', 'week': 9, 'player_id': 84317, 'season': 2020, 'run_block_snaps': 110, 'run_block': 63.8, 'receiving_snaps': 140, 'receiving_rank': 143, 'receiving': 70.1, 'player': 'Harry Ballard III', 'pass_block_snaps': 1, 'pass_block': 61.9, 'offense_rank': 97, 'offense': 70.7, 'discipline': 86.4, 'total_snaps': 251}
# {'position': 'CB', 'unit': 'defense', 'week': 9, 'player_id': 76681, 'season': 2020, 'run_defense_snaps': 253, 'run_defense_rank': 185, 'run_defense': 68.7, 'player': 'Jeremy Webb', 'pass_rush_snaps': 0, 'pass_rush': 60.0, 'discipline': 5.3, 'defense_rank': 83, 'defense': 73.9, 'coverage_snaps': 313, 'coverage_rank': 67, 'coverage': 75.0, 'total_snaps': 637}
# {'position': 'WR', 'unit': 'offense', 'run': 59.5, 'week': 9, 'player_id': 97288, 'season': 2020, 'run_snaps': 1, 'run_block_snaps': 105, 'run_block': 66.3, 'receiving_snaps': 194, 'receiving_rank': 269, 'receiving': 63.7, 'player': 'Tahj Washington', 'offense_rank': 206, 'offense': 63.9, 'discipline': 46.9, 'total_snaps': 367}
# {'position': 'WR', 'unit': 'offense', 'week': 9, 'player_id': 63672, 'season': 2020, 'run_block_snaps': 22, 'run_block': 59.6, 'receiving_snaps': 30, 'receiving': 56.7, 'player': 'Bryce Nunnelly', 'offense': 57.0, 'discipline': 77.0, 'total_snaps': 56}
# {'position': 'LB', 'unit': 'defense', 'week': 9, 'player_id': 75826, 'season': 2020, 'run_defense_snaps': 62, 'run_defense': 57.1, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'Blaze Alldredge', 'pass_rush_snaps': 18, 'pass_rush': 68.3, 'offense': 60.0, 'discipline': 0.0, 'defense': 51.4, 'coverage_snaps': 47, 'coverage': 46.8, 'total_snaps': 134}
# {'position': 'CB', 'unit': 'defense', 'week': 9, 'player_id': 65081, 'season': 2020, 'run_defense_snaps': 87, 'run_defense_rank': 109, 'run_defense': 74.2, 'player': 'Allie Green IV', 'discipline': 0.0, 'defense_rank': 460, 'defense': 48.9, 'coverage_snaps': 133, 'coverage_rank': 391, 'coverage': 47.4, 'total_snaps': 233}
# {'position': 'CB', 'unit': 'defense', 'week': 9, 'player_id': 121345, 'season': 2020, 'run_defense_snaps': 185, 'run_defense_rank': 37, 'run_defense': 80.0, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'Elijah Culp', 'pass_rush_snaps': 1, 'pass_rush': 60.0, 'offense': 60.0, 'discipline': 83.1, 'defense_rank': 9, 'defense': 83.0, 'coverage_snaps': 172, 'coverage_rank': 10, 'coverage': 82.4, 'total_snaps': 431}
# {'position': 'CB', 'unit': 'defense', 'week': 9, 'player_id': 65033, 'season': 2020, 'run_defense_snaps': 91, 'run_defense_rank': 102, 'run_defense': 74.6, 'player': 'Akayleb Evans', 'discipline': 0.0, 'defense_rank': 295, 'defense': 63.5, 'coverage_snaps': 113, 'coverage_rank': 275, 'coverage': 62.2, 'total_snaps': 218}
# {'position': 'LB', 'unit': 'defense', 'week': 9, 'player_id': 138052, 'season': 2020, 'run_defense_snaps': 70, 'run_defense': 81.9, 'player': 'Marvin Pierre', 'pass_rush_snaps': 24, 'pass_rush': 82.9, 'discipline': 6.7, 'defense_rank': 6, 'defense': 88.4, 'coverage_snaps': 78, 'coverage_rank': 15, 'coverage': 82.9, 'total_snaps': 193}
# {'position': 'WR', 'unit': 'offense', 'week': 9, 'player_id': 41966, 'season': 2020, 'run_block_snaps': 77, 'run_block': 66.9, 'receiving_snaps': 130, 'receiving_rank': 353, 'receiving': 60.3, 'player': 'Devaughn Cooper', 'offense_rank': 267, 'offense': 60.5, 'discipline': 31.2, 'total_snaps': 207}
# {'position': 'CB', 'unit': 'defense', 'week': 9, 'player_id': 83253, 'season': 2020, 'run_defense_snaps': 25, 'run_defense': 66.5, 'player': 'DJ Johnson', 'discipline': 76.5, 'defense': 59.4, 'coverage_snaps': 18, 'coverage': 56.5, 'total_snaps': 46}
# {'position': 'WR', 'unit': 'offense', 'pass': 49.9, 'week': 9, 'player_id': 55283, 'season': 2020, 'run_block_snaps': 139, 'run_block': 52.5, 'receiving_snaps': 227, 'receiving_rank': 19, 'receiving': 82.3, 'player': 'Keith Pearson', 'pass_snaps': 1, 'offense_rank': 21, 'offense': 80.3, 'discipline': 86.5, 'total_snaps': 368}
# {'position': 'WR', 'unit': 'offense', 'week': 9, 'player_id': 78784, 'season': 2020, 'run_block_snaps': 106, 'run_block': 55.6, 'receiving_snaps': 193, 'receiving_rank': 470, 'receiving': 54.8, 'player': 'Levar Gumms', 'offense_rank': 352, 'offense': 54.9, 'discipline': 84.8, 'total_snaps': 299}
# {'position': 'ED', 'unit': 'defense', 'week': 9, 'player_id': 55198, 'season': 2020, 'run_defense_snaps': 105, 'run_defense_rank': 94, 'run_defense': 70.6, 'player': 'Jordan Strachan', 'pass_rush_snaps': 134, 'pass_rush_rank': 21, 'pass_rush': 84.9, 'discipline': 28.6, 'defense_rank': 123, 'defense': 71.1, 'coverage_snaps': 59, 'coverage_rank': 59, 'coverage': 47.7, 'total_snaps': 321}
# {'position': 'CB', 'unit': 'defense', 'week': 9, 'player_id': 104234, 'season': 2020, 'run_defense_snaps': 246, 'run_defense_rank': 34, 'run_defense': 81.2, 'player': 'JT Thompson', 'pass_rush_snaps': 1, 'pass_rush': 59.6, 'discipline': 29.9, 'defense_rank': 214, 'defense': 67.6, 'coverage_snaps': 188, 'coverage_rank': 227, 'coverage': 64.8, 'total_snaps': 444}
# {'position': 'LB', 'unit': 'defense', 'week': 9, 'player_id': 63327, 'season': 2020, 'run_defense_snaps': 106, 'run_defense_rank': 233, 'run_defense': 63.6, 'player': 'Zack Woodard', 'pass_rush_snaps': 18, 'pass_rush': 55.7, 'discipline': 79.4, 'defense_rank': 99, 'defense': 73.2, 'coverage_snaps': 131, 'coverage_rank': 16, 'coverage': 81.4, 'total_snaps': 288}
# {'position': 'WR', 'unit': 'offense', 'week': 9, 'player_id': 97215, 'season': 2020, 'receiving_snaps': 1, 'receiving': 59.4, 'player': 'Lincoln Victor', 'offense': 57.9, 'discipline': 63.4, 'total_snaps': 2}
# {'position': 'CB', 'unit': 'defense', 'week': 9, 'player_id': 56122, 'season': 2020, 'run_defense_snaps': 179, 'run_defense_rank': 321, 'run_defense': 58.1, 'player': 'Cam Johnson', 'discipline': 28.8, 'defense_rank': 142, 'defense': 70.7, 'coverage_snaps': 202, 'coverage_rank': 69, 'coverage': 74.7, 'total_snaps': 419}
# {'position': 'CB', 'unit': 'defense', 'week': 9, 'player_id': 97890, 'season': 2020, 'run_defense_snaps': 7, 'run_defense': 57.4, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'David Spaulding', 'offense': 60.0, 'discipline': 71.3, 'defense': 40.6, 'coverage_snaps': 4, 'coverage': 52.0, 'total_snaps': 27}
# {'position': 'CB', 'unit': 'defense', 'week': 9, 'player_id': 102462, 'season': 2020, 'run_defense_snaps': 153, 'run_defense_rank': 125, 'run_defense': 72.7, 'player': 'Tra Fluellen', 'pass_rush_snaps': 5, 'pass_rush': 56.3, 'discipline': 85.1, 'defense_rank': 464, 'defense': 48.1, 'coverage_snaps': 185, 'coverage_rank': 400, 'coverage': 40.4, 'total_snaps': 404}
# {'position': 'WR', 'unit': 'offense', 'run': 63.5, 'week': 9, 'player_id': 102544, 'season': 2020, 'run_snaps': 1, 'run_block_snaps': 61, 'run_block': 86.8, 'receiving_snaps': 98, 'receiving_rank': 53, 'receiving': 76.4, 'player': 'Brandon Sanders', 'offense': 79.9, 'discipline': 82.5, 'total_snaps': 161}
# ...
# {'position': 'LB', 'unit': 'defense', 'week': 8, 'player_id': 173560, 'season': 2024, 'run_defense_snaps': 206, 'run_defense_rank': 698, 'run_defense': 51.3, 'player': 'Jaden Yates', 'pass_rush_snaps': 29, 'pass_rush_rank': 218, 'pass_rush': 58.8, 'discipline': 44.0, 'defense_rank': 548, 'defense': 60.5, 'coverage_snaps': 258, 'coverage_rank': 134, 'coverage': 71.3, 'total_snaps': 535}
# {'position': 'ED', 'unit': 'defense', 'week': 8, 'player_id': 164530, 'season': 2024, 'run_defense_snaps': 116, 'run_defense_rank': 343, 'run_defense': 68.0, 'player': 'Melkart Abou-Jaoude', 'pass_rush_snaps': 143, 'pass_rush_rank': 258, 'pass_rush': 69.7, 'discipline': 52.2, 'defense_rank': 285, 'defense': 70.1, 'coverage_snaps': 2, 'coverage': 60.2, 'total_snaps': 288}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 156723, 'season': 2024, 'run_defense_snaps': 163, 'run_defense_rank': 586, 'run_defense': 50.1, 'player': 'Brent Austin', 'pass_rush_snaps': 3, 'pass_rush': 53.5, 'discipline': 83.7, 'defense_rank': 311, 'defense': 69.4, 'coverage_snaps': 236, 'coverage_rank': 205, 'coverage': 72.7, 'total_snaps': 427}
# {'position': 'ED', 'unit': 'defense', 'week': 8, 'player_id': 172683, 'season': 2024, 'run_defense_snaps': 93, 'run_defense_rank': 191, 'run_defense': 72.8, 'player': 'Brayden Manley', 'pass_rush_snaps': 170, 'pass_rush_rank': 17, 'pass_rush': 87.4, 'discipline': 7.1, 'defense_rank': 39, 'defense': 81.9, 'coverage_snaps': 3, 'coverage': 58.9, 'total_snaps': 278}
# {'position': 'WR', 'unit': 'offense', 'run': 63.7, 'week': 8, 'player_id': 177868, 'season': 2024, 'run_snaps': 1, 'run_block_snaps': 104, 'run_block_rank': 890, 'run_block': 39.4, 'receiving_snaps': 177, 'receiving_rank': 371, 'receiving': 66.5, 'player': 'E. Jai Mason', 'offense_rank': 452, 'offense': 65.0, 'discipline': 82.7, 'total_snaps': 313}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 146043, 'season': 2024, 'run_defense_snaps': 66, 'run_defense': 67.1, 'player': 'Julian Neal', 'pass_rush_snaps': 2, 'pass_rush': 55.5, 'discipline': 81.1, 'defense_rank': 458, 'defense': 65.7, 'coverage_snaps': 137, 'coverage_rank': 471, 'coverage': 65.2, 'total_snaps': 237}
# {'position': 'ED', 'unit': 'defense', 'week': 8, 'player_id': 100437, 'season': 2024, 'run_defense_snaps': 86, 'run_defense_rank': 365, 'run_defense': 67.2, 'player': 'Stephon Wright', 'pass_rush_snaps': 100, 'pass_rush_rank': 162, 'pass_rush': 73.6, 'discipline': 44.8, 'defense_rank': 88, 'defense': 78.2, 'coverage_snaps': 1, 'coverage': 93.0, 'total_snaps': 209}
# {'position': 'LB', 'unit': 'defense', 'week': 8, 'player_id': 170754, 'season': 2024, 'run_defense_snaps': 199, 'run_defense_rank': 305, 'run_defense': 70.3, 'player': 'Michael Montgomery', 'pass_rush_snaps': 18, 'pass_rush': 59.8, 'discipline': 81.3, 'defense_rank': 375, 'defense': 65.7, 'coverage_snaps': 226, 'coverage_rank': 397, 'coverage': 60.1, 'total_snaps': 489}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 141638, 'season': 2024, 'run_defense_snaps': 90, 'run_defense': 65.0, 'receiving_snaps': 1, 'receiving': 57.7, 'player': 'Colby Humphrey', 'pass_rush_snaps': 1, 'pass_rush': 60.0, 'offense': 58.1, 'discipline': 81.6, 'defense_rank': 87, 'defense': 76.8, 'coverage_snaps': 144, 'coverage_rank': 99, 'coverage': 77.5, 'total_snaps': 316}
# {'position': 'LB', 'unit': 'defense', 'week': 8, 'player_id': 165250, 'season': 2024, 'run_defense_snaps': 171, 'run_defense_rank': 2, 'run_defense': 92.2, 'player': 'Gideon Lampron', 'pass_rush_snaps': 43, 'pass_rush_rank': 108, 'pass_rush': 68.4, 'discipline': 83.7, 'defense_rank': 2, 'defense': 91.3, 'coverage_snaps': 97, 'coverage_rank': 34, 'coverage': 79.8, 'total_snaps': 343}
# {'position': 'ED', 'unit': 'defense', 'week': 8, 'player_id': 174925, 'season': 2024, 'run_defense_snaps': 107, 'run_defense_rank': 427, 'run_defense': 65.8, 'player': 'TJ Bush Jr.', 'pass_rush_snaps': 144, 'pass_rush_rank': 70, 'pass_rush': 79.5, 'discipline': 24.3, 'defense_rank': 177, 'defense': 74.1, 'coverage_snaps': 4, 'coverage': 64.1, 'total_snaps': 282}
# {'position': 'WR', 'unit': 'offense', 'week': 8, 'player_id': 163139, 'season': 2024, 'run_block_snaps': 115, 'run_block_rank': 138, 'run_block': 67.5, 'receiving_snaps': 191, 'receiving_rank': 43, 'receiving': 80.7, 'player': 'Chrishon McCray', 'offense_rank': 39, 'offense': 81.0, 'discipline': 84.7, 'total_snaps': 311}
# {'position': 'ED', 'unit': 'defense', 'week': 8, 'player_id': 122670, 'season': 2024, 'run_defense_snaps': 34, 'run_defense': 61.3, 'player': 'Kershawn Fisher', 'pass_rush_snaps': 56, 'pass_rush': 62.9, 'discipline': 81.0, 'defense': 64.3, 'coverage_snaps': 4, 'coverage': 63.6, 'total_snaps': 102}
# {'position': 'ED', 'unit': 'defense', 'week': 8, 'player_id': 122261, 'season': 2024, 'run_defense_snaps': 95, 'run_defense_rank': 50, 'run_defense': 80.5, 'player': 'Tony Anyanwu', 'pass_rush_snaps': 123, 'pass_rush_rank': 490, 'pass_rush': 62.2, 'discipline': 0.0, 'defense_rank': 302, 'defense': 69.8, 'coverage_snaps': 2, 'coverage': 70.3, 'total_snaps': 233}
# {'position': 'ED', 'unit': 'defense', 'week': 8, 'player_id': 174768, 'season': 2024, 'run_defense_snaps': 131, 'run_defense_rank': 771, 'run_defense': 51.9, 'player': 'Cian Slone', 'pass_rush_snaps': 109, 'pass_rush_rank': 387, 'pass_rush': 65.6, 'discipline': 53.4, 'defense_rank': 725, 'defense': 57.8, 'coverage_snaps': 0, 'coverage': 60.6, 'total_snaps': 269}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 161488, 'season': 2024, 'run_defense_snaps': 98, 'run_defense_rank': 607, 'run_defense': 45.0, 'player': 'Tre Bell', 'discipline': 80.2, 'defense_rank': 260, 'defense': 70.8, 'coverage_snaps': 81, 'coverage_rank': 87, 'coverage': 78.2, 'total_snaps': 268}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 175097, 'season': 2024, 'run_defense_snaps': 195, 'run_defense_rank': 52, 'run_defense': 79.4, 'player': 'Andrew Marshall', 'pass_rush_snaps': 8, 'pass_rush_rank': 78, 'pass_rush': 55.6, 'discipline': 85.5, 'defense_rank': 142, 'defense': 74.6, 'coverage_snaps': 275, 'coverage_rank': 199, 'coverage': 73.1, 'total_snaps': 544}
# {'position': 'LB', 'unit': 'defense', 'week': 8, 'player_id': 150093, 'season': 2024, 'run_defense_snaps': 134, 'run_defense_rank': 266, 'run_defense': 71.7, 'player': 'Micah Davey', 'pass_rush_snaps': 20, 'pass_rush': 83.1, 'discipline': 81.7, 'defense_rank': 154, 'defense': 73.1, 'coverage_snaps': 101, 'coverage_rank': 332, 'coverage': 62.3, 'total_snaps': 275}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 162115, 'season': 2024, 'run_defense_snaps': 182, 'run_defense_rank': 307, 'run_defense': 67.2, 'player': 'Jamel Johnson', 'pass_rush_snaps': 1, 'pass_rush': 46.4, 'discipline': 81.6, 'defense_rank': 80, 'defense': 77.1, 'coverage_snaps': 135, 'coverage_rank': 48, 'coverage': 80.7, 'total_snaps': 389}
# {'position': 'WR', 'unit': 'offense', 'week': 8, 'player_id': 144279, 'season': 2024, 'run_block_snaps': 131, 'run_block_rank': 755, 'run_block': 51.1, 'receiving_snaps': 207, 'receiving_rank': 155, 'receiving': 73.4, 'player': 'Eric Rivers', 'offense_rank': 163, 'offense': 72.4, 'discipline': 84.1, 'total_snaps': 338}
# {'position': 'ED', 'unit': 'defense', 'week': 8, 'player_id': 149959, 'season': 2024, 'run_defense_snaps': 71, 'run_defense_rank': 414, 'run_defense': 66.0, 'player': 'Jamall Thompson Jr.', 'pass_rush_snaps': 74, 'pass_rush_rank': 333, 'pass_rush': 67.5, 'discipline': 81.1, 'defense_rank': 260, 'defense': 70.9, 'coverage_snaps': 4, 'coverage': 63.3, 'total_snaps': 162}
# {'position': 'WR', 'unit': 'offense', 'week': 8, 'player_id': 164134, 'season': 2024, 'run_block_snaps': 19, 'run_block': 61.0, 'receiving_snaps': 50, 'receiving': 65.7, 'player': 'JoJo Bermudez', 'offense': 66.2, 'discipline': 77.7, 'total_snaps': 69}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 165156, 'season': 2024, 'run_defense_snaps': 254, 'run_defense_rank': 1, 'run_defense': 92.4, 'player': 'Boogie Trotter', 'pass_rush_snaps': 2, 'pass_rush': 55.7, 'discipline': 88.8, 'defense_rank': 12, 'defense': 84.7, 'coverage_snaps': 255, 'coverage_rank': 91, 'coverage': 77.8, 'total_snaps': 609}
# {'position': 'WR', 'unit': 'offense', 'week': 8, 'player_id': 174167, 'season': 2024, 'run_block_snaps': 16, 'run_block': 60.2, 'receiving_snaps': 37, 'receiving': 62.3, 'player': 'Carlos Hernandez', 'offense': 62.6, 'discipline': 78.9, 'total_snaps': 53}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 156676, 'season': 2024, 'run_defense_snaps': 145, 'run_defense_rank': 360, 'run_defense': 64.5, 'player': 'Matthew McDoom', 'discipline': 82.9, 'defense_rank': 239, 'defense': 71.2, 'coverage_snaps': 163, 'coverage_rank': 241, 'coverage': 71.6, 'total_snaps': 335}
# {'position': 'LB', 'unit': 'defense', 'week': 8, 'player_id': 124277, 'season': 2024, 'run_defense_snaps': 118, 'run_defense_rank': 400, 'run_defense': 66.2, 'player': 'Martavius French', 'pass_rush_snaps': 38, 'pass_rush_rank': 110, 'pass_rush': 68.2, 'discipline': 24.7, 'defense_rank': 494, 'defense': 62.3, 'coverage_snaps': 152, 'coverage_rank': 482, 'coverage': 56.5, 'total_snaps': 330}
# {'position': 'WR', 'unit': 'offense', 'run': 57.5, 'week': 8, 'player_id': 145365, 'season': 2024, 'run_snaps': 1, 'run_block_snaps': 109, 'run_block_rank': 454, 'run_block': 59.4, 'receiving_snaps': 208, 'receiving_rank': 263, 'receiving': 69.1, 'player': 'Levi Wentz', 'offense_rank': 326, 'offense': 67.6, 'discipline': 14.8, 'defense': 60.0, 'coverage_snaps': 1, 'coverage': 60.0, 'total_snaps': 320}
# {'position': 'LB', 'unit': 'defense', 'week': 8, 'player_id': 175078, 'season': 2024, 'run_defense_snaps': 156, 'run_defense_rank': 108, 'run_defense': 79.5, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'Jaxton Eck', 'pass_rush_snaps': 7, 'pass_rush': 62.8, 'offense': 60.0, 'discipline': 81.3, 'defense_rank': 90, 'defense': 76.2, 'coverage_snaps': 199, 'coverage_rank': 144, 'coverage': 70.9, 'total_snaps': 457}
# {'position': 'ED', 'unit': 'defense', 'week': 8, 'player_id': 171816, 'season': 2024, 'run_defense_snaps': 173, 'run_defense_rank': 474, 'run_defense': 64.6, 'player': 'Eriq George', 'pass_rush_snaps': 181, 'pass_rush_rank': 696, 'pass_rush': 56.6, 'discipline': 61.5, 'defense_rank': 661, 'defense': 59.9, 'coverage_snaps': 0, 'coverage': 60.0, 'total_snaps': 363}
# {'position': 'S', 'unit': 'defense', 'week': 8, 'player_id': 161247, 'season': 2024, 'run_defense_snaps': 88, 'run_defense_rank': 418, 'run_defense': 66.4, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'Jayvon Henderson', 'offense': 60.0, 'discipline': 81.0, 'defense_rank': 799, 'defense': 54.6, 'coverage_snaps': 125, 'coverage_rank': 750, 'coverage': 52.4, 'total_snaps': 261}
# {'position': 'LB', 'unit': 'defense', 'week': 8, 'player_id': 189285, 'season': 2024, 'run_defense_snaps': 122, 'run_defense_rank': 107, 'run_defense': 79.6, 'player': 'Ayden Jones', 'pass_rush_snaps': 11, 'pass_rush': 90.2, 'discipline': 82.0, 'defense_rank': 129, 'defense': 74.1, 'coverage_snaps': 122, 'coverage_rank': 482, 'coverage': 56.5, 'total_snaps': 349}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 156813, 'season': 2024, 'run_defense_snaps': 119, 'run_defense_rank': 45, 'run_defense': 80.4, 'player': 'Dainsus Miller', 'discipline': 82.5, 'defense_rank': 203, 'defense': 72.2, 'coverage_snaps': 202, 'coverage_rank': 302, 'coverage': 69.8, 'total_snaps': 364}
# {'position': 'WR', 'unit': 'offense', 'run': 66.8, 'week': 8, 'player_id': 173459, 'season': 2024, 'run_snaps': 4, 'run_block_snaps': 137, 'run_block_rank': 543, 'run_block': 57.2, 'receiving_snaps': 154, 'receiving_rank': 727, 'receiving': 58.6, 'player': 'Caleb Goodie', 'offense_rank': 753, 'offense': 59.1, 'discipline': 46.6, 'total_snaps': 341}
# {'position': 'WR', 'unit': 'offense', 'week': 8, 'player_id': 149833, 'season': 2024, 'run_block_snaps': 158, 'run_block_rank': 483, 'run_block': 58.8, 'receiving_snaps': 183, 'receiving_rank': 19, 'receiving': 83.6, 'player': 'Sam Phillips', 'offense_rank': 23, 'offense': 82.6, 'discipline': 85.4, 'total_snaps': 370}
# {'position': 'CB', 'unit': 'defense', 'run': 57.5, 'week': 8, 'player_id': 141727, 'season': 2024, 'run_snaps': 1, 'run_rank': 3, 'run_defense_snaps': 74, 'run_defense': 54.2, 'run_block_snaps': 1, 'run_block': 60.0, 'player': 'Abraham Williams', 'pass_rush_snaps': 1, 'pass_rush': 58.6, 'offense': 54.4, 'discipline': 85.0, 'defense_rank': 370, 'defense': 67.9, 'coverage_snaps': 103, 'coverage_rank': 282, 'coverage': 70.4, 'total_snaps': 235}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 122908, 'season': 2024, 'run_defense_snaps': 162, 'run_defense_rank': 92, 'run_defense': 76.6, 'player': 'Caleb Offord', 'discipline': 16.8, 'defense_rank': 578, 'defense': 62.6, 'coverage_snaps': 151, 'coverage_rank': 655, 'coverage': 59.9, 'total_snaps': 317}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 163211, 'season': 2024, 'run_defense_snaps': 78, 'run_defense': 49.6, 'player': 'Donavon Platt', 'pass_rush_snaps': 2, 'pass_rush': 56.7, 'discipline': 82.0, 'defense_rank': 614, 'defense': 61.4, 'coverage_snaps': 158, 'coverage_rank': 550, 'coverage': 63.2, 'total_snaps': 244}
# {'position': 'LB', 'unit': 'defense', 'week': 8, 'player_id': 145978, 'season': 2024, 'run_defense_snaps': 102, 'run_defense_rank': 205, 'run_defense': 74.9, 'player': 'Andrew Simpson', 'pass_rush_snaps': 66, 'pass_rush_rank': 74, 'pass_rush': 70.7, 'discipline': 84.2, 'defense_rank': 164, 'defense': 72.8, 'coverage_snaps': 108, 'coverage_rank': 366, 'coverage': 61.1, 'total_snaps': 309}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 172197, 'season': 2024, 'run_defense_snaps': 202, 'run_defense_rank': 245, 'run_defense': 69.6, 'player': 'Dontay Joyner', 'pass_rush_snaps': 6, 'pass_rush': 69.5, 'discipline': 83.2, 'defense_rank': 189, 'defense': 72.6, 'coverage_snaps': 205, 'coverage_rank': 235, 'coverage': 71.7, 'total_snaps': 447}
# {'position': 'LB', 'unit': 'defense', 'week': 8, 'player_id': 169223, 'season': 2024, 'run_defense_snaps': 102, 'run_defense_rank': 659, 'run_defense': 54.7, 'player': 'Max Harris', 'pass_rush_snaps': 30, 'pass_rush_rank': 228, 'pass_rush': 58.0, 'discipline': 1.7, 'defense_rank': 669, 'defense': 55.3, 'coverage_snaps': 92, 'coverage_rank': 399, 'coverage': 60.0, 'total_snaps': 263}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 138424, 'season': 2024, 'run_defense_snaps': 117, 'run_defense_rank': 610, 'run_defense': 43.4, 'player': 'Dylan Tucker', 'discipline': 82.0, 'defense_rank': 559, 'defense': 63.0, 'coverage_snaps': 153, 'coverage_rank': 412, 'coverage': 66.7, 'total_snaps': 297}
# {'position': 'WR', 'unit': 'offense', 'run': 71.7, 'week': 8, 'player_id': 174068, 'season': 2024, 'run_snaps': 9, 'run_defense_snaps': 1, 'run_defense': 60.0, 'run_block_snaps': 80, 'run_block_rank': 398, 'run_block': 60.6, 'receiving_snaps': 115, 'receiving_rank': 43, 'receiving': 80.7, 'player': 'Jacob De Jesus', 'pass_block_snaps': 1, 'pass_block': 70.0, 'offense_rank': 33, 'offense': 81.3, 'discipline': 82.6, 'defense': 60.0, 'total_snaps': 265}
# {'position': 'CB', 'unit': 'defense', 'week': 8, 'player_id': 172547, 'season': 2024, 'run_defense_snaps': 188, 'run_defense_rank': 242, 'run_defense': 69.7, 'receiving_snaps': 1, 'receiving': 59.5, 'player': 'Will James', 'pass_rush_snaps': 1, 'pass_rush': 47.1, 'offense': 59.6, 'discipline': 83.4, 'defense_rank': 394, 'defense': 67.2, 'coverage_snaps': 182, 'coverage_rank': 416, 'coverage': 66.6, 'total_snaps': 446}
# {'position': 'LB', 'unit': 'defense', 'week': 8, 'player_id': 176394, 'season': 2024, 'run_defense_snaps': 137, 'run_defense_rank': 753, 'run_defense': 36.6, 'player': 'Isaiah Chisom', 'pass_rush_snaps': 25, 'pass_rush': 49.6, 'discipline': 0.0, 'defense_rank': 766, 'defense': 45.4, 'coverage_snaps': 144, 'coverage_rank': 260, 'coverage': 64.9, 'total_snaps': 343}

# %%
import json

column_list = []


with open("season_grades_filtered.json", "r") as fin:
    data = json.load(fin)

season_grades_filtered_df = pd.DataFrame(data)
# season_grades_filtered_df

for entry in data:
    for key in entry:
        # print(key)
        if key not in column_list:
            column_list.append(key)
    # break

print(column_list)
season_grades_filtered_df
# Out:
# ['position', 'unit', 'week', 'player_id', 'season', 'run_defense_snaps', 'run_defense', 'player', 'pass_rush_snaps', 'pass_rush', 'discipline', 'defense', 'coverage_snaps', 'coverage_rank', 'coverage', 'total_snaps', 'run_block_snaps', 'run_block', 'receiving_snaps', 'receiving', 'offense_rank', 'offense', 'defense_rank', 'run_defense_rank', 'pass_rush_rank', 'receiving_rank', 'pass_block_snaps', 'pass_block', 'run', 'run_snaps', 'pass', 'pass_snaps', 'pass_rank', 'run_block_rank', 'pass_block_rank', 'run_rank']
#       position     unit  week  player_id  season  run_defense_snaps  \
# 0           ED  defense     4      55198    2020               28.0
# 1           WR  offense     4      42095    2020                NaN
# 2           CB  defense     4     121345    2020               33.0
# 3           LB  defense     4      63327    2020               28.0
# 4           CB  defense     4     136842    2020               49.0
# ...        ...      ...   ...        ...     ...                ...
# 11110       LB  defense     8     169223    2024              102.0
# 11111       CB  defense     8     138424    2024              117.0
# 11112       WR  offense     8     174068    2024                1.0
# 11113       CB  defense     8     172547    2024              188.0
# 11114       LB  defense     8     176394    2024              137.0
#
#        run_defense           player  pass_rush_snaps  pass_rush  ...  \
# 0             66.6  Jordan Strachan             25.0       56.6  ...
# 1              NaN  Jahcour Pearson              NaN        NaN  ...
# 2             88.0      Elijah Culp              NaN        NaN  ...
# 3             66.6     Zack Woodard              7.0       52.1  ...
# 4             61.6     Ridge Texada             14.0       49.7  ...
# ...            ...              ...              ...        ...  ...
# 11110         54.7       Max Harris             30.0       58.0  ...
# 11111         43.4     Dylan Tucker              NaN        NaN  ...
# 11112         60.0   Jacob De Jesus              NaN        NaN  ...
# 11113         69.7       Will James              1.0       47.1  ...
# 11114         36.6    Isaiah Chisom             25.0       49.6  ...
#
#        pass_block_snaps  pass_block   run  run_snaps  pass  pass_snaps  \
# 0                   NaN         NaN   NaN        NaN   NaN         NaN
# 1                   NaN         NaN   NaN        NaN   NaN         NaN
# 2                   NaN         NaN   NaN        NaN   NaN         NaN
# 3                   NaN         NaN   NaN        NaN   NaN         NaN
# 4                   NaN         NaN   NaN        NaN   NaN         NaN
# ...                 ...         ...   ...        ...   ...         ...
# 11110               NaN         NaN   NaN        NaN   NaN         NaN
# 11111               NaN         NaN   NaN        NaN   NaN         NaN
# 11112               1.0        70.0  71.7        9.0   NaN         NaN
# 11113               NaN         NaN   NaN        NaN   NaN         NaN
# 11114               NaN         NaN   NaN        NaN   NaN         NaN
#
#        pass_rank  run_block_rank  pass_block_rank  run_rank
# 0            NaN             NaN              NaN       NaN
# 1            NaN             NaN              NaN       NaN
# 2            NaN             NaN              NaN       NaN
# 3            NaN             NaN              NaN       NaN
# 4            NaN             NaN              NaN       NaN
# ...          ...             ...              ...       ...
# 11110        NaN             NaN              NaN       NaN
# 11111        NaN             NaN              NaN       NaN
# 11112        NaN           398.0              NaN       NaN
# 11113        NaN             NaN              NaN       NaN
# 11114        NaN             NaN              NaN       NaN
#
# [11115 rows x 36 columns]

# %%
agg_dict = {
    "position": "first",
    "unit": "first",
    "player": "first",

    "run_defense_snaps": "sum",
    "pass_rush_snaps": "sum",
    "coverage_snaps": "sum",
    "total_snaps": "sum",
    "run_block_snaps": "sum",
    "receiving_snaps": "sum",
    "pass_block_snaps": "sum",
    "run_snaps": "sum",
    "pass_snaps": "sum",

    "run_defense": "mean",
    "pass_rush": "mean",
    "coverage": "mean",
    "discipline": "mean",
    "defense": "mean",
    "run_block": "mean",
    "receiving": "mean",
    "pass_block": "mean",
    "run": "mean",
    "pass": "mean",
    "offense": "mean",

    "coverage_rank": "mean",
    "offense_rank": "mean",
    "defense_rank": "mean",
    "run_defense_rank": "mean",
    "pass_rush_rank": "mean",
    "receiving_rank": "mean",
    "pass_rank": "mean",
    "run_block_rank": "mean",
    "pass_block_rank": "mean",
    "run_rank": "mean"
}

df_agg = season_grades_filtered_df.groupby(["player_id", "season"]).agg(agg_dict).reset_index().sort_values(["position", "season"])

wick_combine = duckdb.query("""

SELECT *
FROM df_agg JOIN transfer_player_career_wicks ON df_agg.player_id = transfer_player_career_wicks.pff_player_id AND df_agg.season = transfer_player_career_wicks.season
ORDER BY df_agg.position
""").to_df()


# df_agg.to_csv("agged_season_stats.csv", index=False)
wick_combine.to_csv("clean_data/agged_season_stats.csv", index=False)
